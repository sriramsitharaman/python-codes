# %%
import csv
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\Train\\"
inputFile="Train-Hilary"
from io import StringIO
#inp=open(folder+inputFile+".csv")

with open(folder+inputFile+".csv", encoding='ISO-8859-1') as file_obj:
    reader = csv.reader(file_obj,skipinitialspace=True)
    outputFile=open(folder+"Words\\"+inputFile+".txt","wb")
    for row in reader:
        words=preprocess(row[0])
        #print(words)    
        for word in words:
            #print (str.encode(word),type(str.encode(word)))
            outputFile.write(str.encode(word+"\n"))
        outputFile.write(str.encode("\n"))
outputFile.close()

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

tweet = '@tedcruz And, #HandOverTheServer she wiped clean + 30k deleted emails, explains dereliction of duty/lies re #Benghazi,etc #tcot'
print()

# %%
outputFile.close()

# %%
count=0
outputFile=open(folder+"WordVector.txt","w")
with open(folder+inputFile, encoding='ISO-8859-1') as file_obj:
    reader = csv.reader(file_obj,skipinitialspace=True)
    for row in reader:
        words=preprocess(row[0])
        print (words)
        LowerWords=[x.lower() for x in words]
        #print(words)
        cols=[]
        wordList=open(folder+"FinalWords.txt")
        with open(folder+"FinalWords.txt", encoding='ISO-8859-1') as wordFile_obj:
            for col in wordFile_obj:
                if col.replace("\n","").lower() in LowerWords:
                    cols.append(1)
                    #print ("hi")
                else:
                    cols.append(0)
            outputFile.write("|".join([str(x) for x in cols])+"\n")
        count+=1
        if count%50==0:
            print (count)

outputFile.close()

# %%
import csv
from os import listdir
from os.path import isfile, join
from io import StringIO
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\Train\\Words\\POSTagged-Words\\"
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]
for file in onlyfiles:
    LineCount=0
    print(file)
    out=open(folder+"Word-Tags\\Output-"+file,"w")
    out2=open(folder+"Word-Tags\\Output-Final-"+file,"w")
    out.write("Word|Tag\n")
    inp=open(folder+file)
    #file_obj = StringIO(inp.read().decode())
    tagDict=dict()
    with open(folder+file,"rt") as file_obj:
        reader = csv.reader(file_obj,skipinitialspace=True,delimiter="\t")
        for row in reader:
            print (row)
            if LineCount>11:
                if len(row)>0:
                    line=("|".join(row[0].split())).replace("\n","")
                    out.write(line+"\n")
                    tag=(row[0]).replace("\n","")
                    for i in range(1,6):
                        if len(row[i])>0:
                            tag=row[i]
                            break
                    word=(row[0]).replace("\n","")
                    if tag[0]=="N" or tag[0]=="V" or tag[0]=="R":
                        if word in tagDict and tag not in tagDict[word]:
                            tagDict[word].append(tag)
                        else:
                            tagDict[word]=[tag]
        
            LineCount+=1
    print (tagDict)
# Out:
# list-Train-Abortion.txt
# ['laid', 'VBN']
# ['law', 'NN']
# ['abortion', 'NN']
# ['bioethics', 'JJ']
# ['class', 'NN']
# ['#Catholic', 'NNP']
# ['@tooprettyclub', 'NN']
# ['Are', 'VBP']
# ['OK', 'JJ']
# ['#GOP', 'NNP']
# ['males', 'NNS']
# ['telling', 'VBG']
# ["can't", 'VB']
# ['do', 'VB']
# ['own', 'JJ']
# ['body', 'NN']
# ["don't", 'VBP']
# ['want', 'VB']
# ['kid', 'NN']
# ['put', 'VBD']
# ['adoption', 'NN']
# ['#sorrynotsorry', 'JJ']
# ['@RedAlert', 'NNP']
# ['be', 'VB']
# ['stigma', 'NN']
# ['butchering', 'VBG']
# ['pre-born', 'JJ']
# ['children', 'NNS']
# ['horrendous', 'JJ']
# ['crime', 'NN']
# ['humanity', 'NN']
# ['#murder', 'NN']
# ["isn't", 'JJS']
# ['problem', 'NN']
# ['enough', 'JJ']
# ['faith', 'NN']
# ['#gaystapo', 'NN']
# ['#socialism', 'NN']
# ['Life', 'NNP']
# ['is', 'VBZ']
# ['first', 'JJ']
# ['basic', 'JJ']
# ['human', 'JJ']
# ['right', 'NN']
# ['Rise', 'NN']
# ['Shine', 'NNP']
# ['new', 'JJ']
# ['day', 'NN']
# ["you're", 'JJ']
# ['alive', 'JJ']
# ['Thank', 'VB']
# ['God', 'NNP']
# ['precious', 'JJ']
# ['life', 'NN']
# ['#Christian', 'JJ']
# ['#Catholic', 'JJ']
# ['#TeamJesus', 'NNS']
# ['Lmao', 'NNP']
# ['school', 'NN']
# ['thinks', 'VBZ']
# ['giving', 'VBG']
# ['women', 'NNS']
# ['feminism', 'NN']
# ['know', 'VB']
# ['#wtf', 'NN']
# ['@AsaSoltan', 'NNP']
# ['putting', 'VBG']
# ['choices', 'NNS']
# ['won', 'VBD']
# ['heart', 'NN']
# ['Yaaaaaas', 'NNP']
# ['#shahs', 'NNS']
# ['Last', 'JJ']
# ['meeting', 'NN']
# ['year', 'NN']
# ['tonight', 'NN']
# ['pm', 'NN']
# ['Case', 'NNP']
# ['Hall', 'NNP']
# ['room', 'NN']
# ['Come', 'VB']
# ['Pizza', 'NNP']
# ['pop', 'NN']
# ['provided', 'VBN']
# ['FACT', 'NN']
# ['%', 'NN']
# ["today's", 'JJ']
# ['population', 'NN']
# ['equivalent', 'JJ']
# ['residents', 'NNS']
# ['New', 'NNP']
# ['York', 'NNP']
# ['Florida', 'NNP']
# ['Pennsylvania', 'NNP']
# ["Where's", 'VBZ']
# ['outrage', 'NN']
# ['say', 'VBP']
# ["isn't", 'JJ']
# ['listening', 'NN']
# ['look', 'VB']
# ['radar', 'NN']
# ['today', 'NN']
# ['#prayfornepal', 'JJ']
# ['believe', 'VBP']
# ['power', 'NN']
# ['#Nepal', 'NNP']
# ['#Baltimore', 'NNP']
# ['#ISIS', 'NNP']
# ['#Kenya', 'NNP']
# ['#GenderChange', 'NNP']
# ['#Injustice', 'NNP']
# ['#Slavery', 'NNP']
# ['#Racism', 'NNP']
# ['#MiddleEast', 'NNP']
# ['Planned', 'NNP']
# ['Parenthood', 'NNP']
# ['lines', 'NNS']
# ['pockets', 'NNS']
# ['sacrificing', 'VBG']
# ['need', 'NN']
# ['altar', 'NN']
# ['progressive', 'JJ']
# ['try', 'VB']
# ['resolve', 'VB']
# ['problems', 'NNS']
# ['eliminating', 'VBG']
# ['#PopeFrancis', 'NNP']
# ['RT', 'NNP']
# ['@TheKeyisPrayer', 'NNP']
# ['give', 'VB']
# ['wrong', 'JJ']
# ['Abraham', 'NNP']
# ['Lincoln', 'NNP']
# ['live', 'VBP']
# ['world', 'NN']
# ['people', 'NNS']
# ['care', 'VBP']
# ['more', 'JJR']
# ['religious', 'JJ']
# ['rights', 'NNS']
# ['consent', 'NN']
# ['reproductive', 'JJ']
# ['remind', 'VBP']
# ['love', 'NN']
# ['means', 'VBZ']
# ['willing', 'JJ']
# ['hurts', 'VBZ']
# ['Mother', 'NNP']
# ['Teresa', 'NNP']
# ['beautiful', 'JJ']
# ['choice', 'NN']
# ['teacher', 'NN']
# ['said', 'VBD']
# ["embroyo's", 'NNS']
# ['nothing', 'NN']
# ['skin', 'NN']
# ['+', 'JJ']
# ['blood', 'NN']
# ['was', 'VBD']
# ['fine', 'JJ']
# ['#smartlady', 'NN']
# ['@ShowTruth', 'NNP']
# ['Keeping', 'VBG']
# ['pregnant', 'JJ']
# ['safe', 'JJ']
# ['great', 'JJ']
# ['reason', 'NN']
# ['@rosaryrevival', 'NN']
# ['#PrayTheRosary', 'VBP']
# ['forget', 'VBP']
# ['#Prayforpersecutedchurch', 'NNP']
# ['#PrayForIsrael', 'NNP']
# ['#PrayForUkraine', 'NNP']
# ['#cogar', 'JJ']
# ['@RefCom_ie', 'NNP']
# ['get', 'VB']
# ['#questions', 'NNS']
# ["#ireland's", 'NNS']
# ['#dail', 'NN']
# ['stuck', 'VBN']
# ["We'll", 'NNP']
# ['#help', 'NN']
# ['#drugswar', 'JJ']
# ['#landwar', 'JJ']
# ['#etc', 'NN']
# ['#tanks', 'NNS']
# ['Yep', 'NNP']
# ['Defunding', 'NNP']
# ['PP', 'NNP']
# ["won't", 'NN']
# ['mean', 'VBP']
# ['fewer', 'JJR']
# ['abortions', 'NNS']
# ['mean', 'VB']
# ['dead', 'JJ']
# ['#prochoice', 'JJ']
# ['@mrprolife', 'JJ']
# ['force', 'VB']
# ['woman', 'NN']
# ['risk', 'VB']
# ['health', 'NN']
# ['sanity', 'NN']
# ['continue', 'VB']
# ['doomed', 'JJ']
# ['pregnancy', 'NN']
# ['someone', 'NN']
# ['wants', 'VBZ']
# ['have', 'VB']
# ['person', 'NN']
# ['carrying', 'VBG']
# ['agree', 'VB']
# ['gay', 'JJ']
# ['marriage', 'NN']
# ['agree', 'VBP']
# ['pro-life', 'JJ']
# ['adopt', 'VB']
# ['babies', 'NNS']
# ['been', 'VBN']
# ['aborted', 'VBN']
# ['Manila', 'NNP']
# ['TV', 'NNP']
# ['Monday', 'NNP']
# ['#Pacquiao', 'NNP']
# ['appeals', 'NNS']
# ['@IndonesiaPresident', 'NNP']
# ["don't", 'NN']
# ['execute', 'VB']
# ['#MaryJaneVeloso', 'NNP']
# ['#deathRow', 'NN']
# ['#drugTrafficking', 'NN']
# ['Sorry', 'JJ']
# ['watched', 'VBD']
# ['#AfterTiller', 'NNP']
# ['gave', 'VBD']
# ['whole', 'JJ']
# ['perspective', 'NN']
# ["woman's", 'JJ']
# ['choose', 'VB']
# ['#womensRights', 'NNS']
# ['@explicit0ceans', 'NNS']
# ['want', 'VBP']
# ['make', 'VB']
# ['have', 'VBP']
# ['kids', 'NNS']
# ['Esp', 'NNP']
# ["they're", 'VBP']
# ['prepared', 'VBN']
# ['Makes', 'VBZ']
# ['sense', 'NN']
# ['TRUE', 'JJ']
# ['progressives', 'NNS']
# ['work', 'VBP']
# ['greater', 'JJR']
# ['inclusion', 'NN']
# ['protections', 'NNS']
# ['marginalized', 'VBN']
# ['Standing', 'VBG']
# ['unborn', 'NN']
# ['MT', 'NNP']
# ['@ProLifePolitics', 'NNPS']
# ['Senate', 'NNP']
# ['vote', 'NN']
# ['SC', 'NNP']
# ['Pain-Capable', 'NNP']
# ['Unborn', 'NNP']
# ['Child', 'NNP']
# ['Protection', 'NNP']
# ['Act', 'NNP']
# ['early', 'JJ']
# ['Wed', 'NNP']
# ['Contact', 'NN']
# ['senators', 'NNS']
# ['Equal', 'NNP']
# ['pay', 'VB']
# ['equal', 'JJ']
# ['work', 'NN']
# ['YES', 'NNP']
# ['Freedom', 'NN']
# ['fear', 'NN']
# ['rape', 'NN']
# ['sexual', 'JJ']
# ['objectification', 'NN']
# ['abort', 'VB']
# ["don't", 'JJ']
# ['care', 'NN']
# ['having', 'VBG']
# ['sex', 'NN']
# ["there's", 'VBZ']
# ['involved', 'VBN']
# ['Today', 'NNP']
# ['am', 'VBP']
# ['grateful', 'JJ']
# ['control', 'VB']
# ['govt', 'JJ']
# ['influence', 'NN']
# ['#antichoice', 'JJ']
# ['leaders', 'NNS']
# ['stop', 'VB']
# ['#abvote', 'VB']
# ['most', 'JJS']
# ['insurance', 'NN']
# ['plans', 'VBZ']
# ['cover', 'NN']
# ['price', 'NN']
# ['high', 'JJ']
# ['@Britt_Ghiroli', 'NNP']
# ['Mayor', 'NNP']
# ['Baltimore', 'NNP']
# ['rioters', 'NNS']
# ['#BlackLivesMatter', 'NNP']
# ['#Except2Democrats', 'NNP']
# ['#Sanger', 'NNP']
# ['much', 'JJ']
# ['fun', 'NN']
# ['younger', 'JJR']
# ['friends', 'NNS']
# ['expecting', 'VBG']
# ['#beentheredonethat', 'JJ']
# ['#chooselife', 'JJ']
# ['illegal', 'JJ']
# ['kill', 'VB']
# ['unhatched', 'JJ']
# ['eagle', 'JJ']
# ['egg', 'NN']
# ['legal', 'JJ']
# ['unborn', 'JJ']
# ['baby', 'NN']
# ['isright', 'NN']
# ['refuse', 'VBP']
# ['let', 'VB']
# ['shame', 'NN']
# ['insult', 'NN']
# ['accessing', 'JJ']
# ['healthcare', 'NN']
# ["you're", 'NN']
# ['pro-birth', 'JJ']
# ['support', 'VB']
# ['#makesnosense', 'JJ']
# ['#prowomen', 'NNS']
# ['U', 'NNP']
# ["isn't", 'VBP']
# ['funny', 'JJ']
# ['Male', 'JJ']
# ['politicians', 'NNS']
# ['deciding', 'VBG']
# ["body's", 'NNS']
# ['born', 'VBN']
# ['months', 'NNS']
# ['premature', 'JJ']
# ["I'm", 'NNP']
# ['killing', 'VBG']
# ['country', 'NN']
# ["can't", 'VBP']
# ['cause', 'VB']
# ['claim', 'VBP']
# ['made', 'VBD']
# ['mistake', 'NN']
# ['nobody', 'NN']
# ['go', 'VB']
# ['jail', 'NN']
# ['spouse', 'NN']
# ['@Corey_Frizzell', 'NNP']
# ['@PEILiberalParty', 'NNP']
# ['Islanders', 'NNPS']
# ['different', 'JJ']
# ['definitions', 'NNS']
# ['timely', 'JJ']
# ['access', 'NN']
# ['#irony', 'NN']
# ['#peipoli', 'NNS']
# ['#peivotes', 'NNS']
# ['@Docjp', 'NNP']
# ['Pressure', 'NN']
# ["It's", 'NNP']
# ['job', 'NN']
# ['failing', 'VBG']
# ['promises', 'NNS']
# ['#PJNET', 'NNP']
# ['#Amnesty', 'NNP']
# ['#Obamacare', 'NNP']
# ['love', 'VBP']
# ['#liberals', 'NNS']
# ['accuse', 'VBP']
# ['#conservatives', 'NNS']
# ['war', 'NN']
# ['fund', 'VB']
# ['Help', 'VB']
# ['friend', 'NN']
# ['figure', 'NN']
# ["they're", 'JJ']
# ['going', 'VBG']
# ['stay', 'VB']
# ['need', 'VBP']
# ['spend', 'VB']
# ['night', 'NN']
# ['@JimDDaniels1', 'NNP']
# ['Plenty', 'NNP']
# ['reasons', 'NNS']
# ['Christians', 'NNS']
# ['Hillary', 'NNP']
# ['least', 'JJS']
# ['mind', 'NN']
# ['stand', 'NN']
# ['w', 'VB']
# ['/', 'JJ']
# ['Dems', 'NNS']
# ['understand', 'VB']
# ['Pro-Choice', 'JJ']
# ['matter', 'NN']
# ["it's", 'NNS']
# ['weeks', 'NNS']
# ['old', 'JJ']
# ['years', 'NNS']
# ['#SemST', 'NNP']
# ["Let's", 'NNS']
# ['ok', 'VBP']
# ['lbs', 'NNS']
# ['uterus', 'NN']
# ['@DWStweets', 'NNP']
# ['#DNC', 'NNP']
# ['#Clinton2016', 'NNP']
# ['@HillaryforIA', 'NNP']
# ['#ProCompromise', 'NNP']
# ['@glennbeck', 'NN']
# ['like', 'VB']
# ['see', 'VB']
# ['poll', 'NN']
# ['many', 'JJ']
# ['doctors', 'NNS']
# ['told', 'VBN']
# ['No', 'NNP']
# ['required', 'VBN']
# ['case', 'NN']
# ['Democrats', 'NNPS']
# ['AGAINST', 'NNP']
# ['Personhood', 'NNP']
# ['perceive', 'VBP']
# ['legislation', 'NN']
# ['recognize', 'VB']
# ['#Personhood', 'NNP']
# ['#Colorado', 'NNP']
# ['@CultureShifting', 'NNP']
# ['draw', 'VB']
# ['line', 'NN']
# ["I've", 'NNP']
# ['drawn', 'VBN']
# ['Nonsense', 'NN']
# ['lady', 'NN']
# ['needs', 'VBZ']
# ['mental', 'JJ']
# ['illness', 'NN']
# ['serious', 'JJ']
# ['issue', 'NN']
# ['@createdequalorg', 'NN']
# ['video', 'NN']
# ['seeing', 'VBG']
# ['being', 'NN']
# ['@StandTrue', 'JJ']
# ['@liveaction_news', 'NNS']
# ['@collegefix', 'VB']
# ['@LifeSite', 'JJ']
# ['#prolife', 'NN']
# ["We're", 'NNP']
# ["aren't", 'VB']
# ['same', 'JJ']
# ['worth', 'JJ']
# ['saving', 'NN']
# ['J', 'NNP']
# ['K', 'NNP']
# ['Rowling', 'NNP']
# ['snitched', 'VBN']
# ['mom', 'NN']
# ['playing', 'VBG']
# ['naked', 'JJ']
# ['twister', 'NN']
# ['teens', 'NNS']
# ['bet', 'VBD']
# ['Cock', 'NNP']
# ['blocking', 'VBG']
# ['ass', 'JJ']
# ['#SB724', 'NNP']
# ['passes', 'VBZ']
# ['Sen', 'NNP']
# ['Judiciary', 'NNP']
# ['Cmte', 'NNP']
# ['bill', 'NN']
# ['effort', 'NN']
# ['personal', 'JJ']
# ['private', 'JJ']
# ['medical', 'JJ']
# ['decision', 'NN']
# ['#SemST', 'NN']
# ['@GrumpyOldGuy2', 'NNP']
# ['#DebbieWashermanSchultz', 'NNP']
# ['has', 'VBZ']
# ['voice', 'NN']
# ['doctor', 'NN']
# ['speaks', 'VBZ']
# ['askin', 'JJ']
# ['needed', 'JJ']
# ['procedure', 'NN']
# ['available', 'JJ']
# ['RW', 'NNP']
# ['men', 'NNS']
# ["women's", 'JJ']
# ['decisions', 'NNS']
# ['Sad', 'JJ']
# ['huh', 'JJ']
# ['@ProLifeYouth', 'NNP']
# ['seems', 'VBZ']
# ['clear', 'JJ']
# ['daylight', 'NN']
# ['Ghandi', 'NNP']
# ['#ProLifeYouth', 'NNP']
# ['@LilaGraceRose', 'NNP']
# ['defunding', 'JJ']
# ['Govt', 'NNP']
# ['cannot', 'JJ']
# ['chemo', 'NN']
# ['fetus', 'NN']
# ['live', 'VB']
# ['#JulieBorowski', 'NNP']
# ['#reproductiverights', 'JJ']
# ["person's", 'VBZ']
# ['small', 'JJ']
# ['Dr', 'NN']
# ['Suess', 'NNP']
# ['#WAAR', 'NNP']
# ['allowed', 'VBN']
# ['show', 'VB']
# ['correct', 'JJ']
# ['photos', 'NNS']
# ['contraception', 'NN']
# ['use', 'NN']
# ['family', 'NN']
# ['planning', 'NN']
# ['table', 'NN']
# ['#StopAbortion', 'JJ']
# ['Thanks', 'NNS']
# ['spoken', 'VBN']
# ['truth', 'NN']
# ['@DanaPerino', 'NNP']
# ['DO', 'NNP']
# ['nation', 'NN']
# ['protect', 'VB']
# ['innocent', 'JJ']
# ['#TheFive', 'NNP']
# ['#CCOT', 'NNP']
# ['#RNC', 'NNP']
# ['@LuM1996', 'NNP']
# ['@KurtSchlichter', 'NNP']
# ['#Obama', 'NNP']
# ['cares', 'VBZ']
# ['deserters', 'NNS']
# ['#ProtectTheUnprotected', 'VBN']
# ['#AntiAbortion', 'JJ']
# ['Dear', 'NNP']
# ['Nuns', 'NNPS']
# ['advocacy', 'NN']
# ['tax', 'NN']
# ['paying', 'VBG']
# ['weird', 'JJ']
# ['#war', 'JJ']
# ['#Iraq', 'NNP']
# ['#deathpenalty', 'NN']
# ['#taxespayforthistoo', 'NN']
# ['#TaxpayerPride', 'NNP']
# ['noticed', 'VBD']
# ['everybody', 'NN']
# ['Abortion', 'NNP']
# ['born-Ronald', 'JJ']
# ['Reagan', 'NNP']
# ['#LetthemLive', 'NNP']
# ['#AllLivesMatter', 'NNP']
# ['Follow', 'VB']
# ['#Patriot', 'NNP']
# ['>', 'NNP']
# ['@Enuffis2Much', 'NNP']
# ['following', 'VBG']
# ['#Truth', 'NNP']
# ['#Liberty', 'NNP']
# ['#Justice', 'NNP']
# ['#ProIsrael', 'NNP']
# ['#WakeUpAmerica', 'NNP']
# ['#FreeAmirNow', 'NNP']
# ['@DRUDGE_REPORT', 'NNP']
# ['sure', 'JJ']
# ['wonder', 'VBP']
# ['critics', 'NNS']
# ['Patient', 'NNP']
# ['advocate', 'NN']
# ['Stephen', 'NNP']
# ['Casey', 'NNP']
# ['Texas', 'NNP']
# ['Center', 'NNP']
# ['Defense', 'NNP']
# ['supports', 'VBZ']
# ['#HB3074', 'NN']
# ['#TXlege', 'NNP']
# ['red', 'JJ']
# ['faced', 'VBN']
# ['frothing', 'VBG']
# ['death', 'NN']
# ['penalty', 'NN']
# ['wondering', 'VBG']
# ['#deathpenalty', 'JJ']
# ['#SemST', 'NNS']
# ['Hey', 'NNP']
# ['Megan--a', 'NNP']
# ["baby's", 'NNS']
# ['starts', 'VBZ']
# ['beating', 'VBG']
# ['days', 'NNS']
# ['conception', 'NN']
# ['time', 'NN']
# ['right', 'JJ']
# ['end', 'VB']
# ['#kellyfile', 'JJ']
# ['@AzzarelliJim', 'NNP']
# ['birth', 'NN']
# ['wills', 'NNS']
# ['#rapeculture', 'NN']
# ['argue', 'VB']
# ['benefits', 'NNS']
# ['making', 'VBG']
# ['only', 'JJ']
# ['way', 'NN']
# ['dismiss', 'VB']
# ["that's", 'JJ']
# ['b', 'NN']
# ['prochoice', 'NN']
# ['had', 'VBD']
# ['miscarriage', 'JJ']
# ['prochoice', 'JJ']
# ['@HillaryClinton', 'NNP']
# ["Don't", 'NNP']
# ['say', 'VB']
# ['deserve', 'VBP']
# ['chances', 'NNS']
# ['know', 'VBP']
# ["what's", 'NNS']
# ['best', 'JJS']
# ['happiness', 'NN']
# ['being', 'VBG']
# ['@RyanDeloosh', 'NNP']
# ['u', 'NN']
# ['smash', 'VB']
# ['ur', 'JJ']
# ['head', 'NN']
# ['solid', 'JJ']
# ['wall', 'NN']
# ['made', 'VBN']
# ['steel', 'NN']
# ['shore', 'VB']
# ['honay', 'JJ']
# ['#urchoice', 'JJ']
# ['Assaulting', 'NNP']
# ['manipulating', 'VBG']
# ["doesn't", 'VBP']
# ['reduce', 'VB']
# ['@jemimakirke', 'VB']
# ['hat', 'NN']
# ['speaking', 'VBG']
# ['something', 'NN']
# ['discussed', 'VBN']
# ['anyone', 'NN']
# ['Anti-vaxxers', 'NNS']
# ['idiotic', 'JJ']
# ['bunch', 'NN']
# ['guys', 'NNS']
# ['Vaccinate', 'NNP']
# ['#conformcomics', 'NNS']
# ['#marvel', 'VB']
# ['#dc', 'JJ']
# ['need', 'VB']
# ['figure', 'VB']
# ['forbid', 'VBD']
# ["you'd", 'VBN']
# ['walk', 'VB']
# ['mile', 'NN']
# ['shoes', 'NNS']
# ['like', 'VBP']
# ['anything', 'NN']
# ['ready', 'JJ']
# ['child', 'NN']
# ['were', 'VBD']
# ['raped', 'VBN']
# ['theres', 'VBZ']
# ['adopting', 'VBG']
# ['@pari_passu', 'NNP']
# ['Religious', 'NNP']
# ['Right', 'NNP']
# ['keep', 'VB']
# ['church', 'NN']
# ['@TheFullBug', 'NNP']
# ['Dehumanizing', 'NNP']
# ['dehumanizing', 'VBG']
# ["They're", 'NNP']
# ['walking', 'VBG']
# ['incubators', 'NNS']
# ['chilling', 'JJ']
# ['reply', 'NN']
# ['asked', 'VBN']
# ['support', 'VBP']
# ['aborting', 'VBG']
# ['pound', 'NN']
# ['ridiculous', 'JJ']
# ['hour', 'NN']
# ['#protectthezone', 'VB']
# ['#Alabama', 'NNP']
# ['Tip', 'NNP']
# ['protesters', 'NNS']
# ['goal', 'NN']
# ['change', 'VB']
# ['minds', 'NNS']
# ['rational', 'JJ']
# ['adults', 'NNS']
# ['scar', 'NN']
# ['little', 'JJ']
# ['#PGH', 'NNP']
# ['Good', 'JJ']
# ['morning', 'NN']
# ['Patriots', 'NNPS']
# ['let', 'VBD']
# ['continue', 'VBP']
# ['Pray', 'VB']
# ['#UnBorn', 'NNP']
# ['given', 'VBN']
# ['#ccot', 'JJ']
# ['greatest', 'JJS']
# ['blessing', 'NN']
# ['bestowed', 'VBN']
# ['man', 'NN']
# ['Pope', 'NNP']
# ['Francis', 'NNP']
# ['#LifeisaGift', 'NNP']
# ['mistakes', 'NNS']
# ['Do', 'VBP']
# ['#humandignity', 'NN']
# ['@JustinTrudeau', 'NNP']
# ['plan', 'VBP']
# ['tell', 'VB']
# ['@WadePEILiberal', 'JJ']
# ['PEI', 'NNP']
# ['Excellent', 'NNP']
# ['speed-dating', 'VBG']
# ['#ethics', 'NNS']
# ['discussion', 'NN']
# ['Yr9', 'NNP']
# ['#morality', 'NN']
# ['UB', 'NNP']
# ['Students', 'NNS']
# ['North', 'NNP']
# ['Campus', 'NNP']
# ['Student', 'NNP']
# ['Union', 'NNP']
# ['@sinnfeinireland', 'NN']
# ['SinnFein', 'NNP']
# ['voted', 'VBD']
# ['sick', 'JJ']
# ['endorse', 'VB']
# ['@WadePEILiberal', 'NNP']
# ["who'd", 'VBD']
# ['able', 'JJ']
# ['run', 'VB']
# ['fed', 'NN']
# ['@liberal_party', 'NN']
# ['#peipoli', 'NNP']
# ['slaying', 'NN']
# ['souls', 'NNS']
# ['offered', 'VBD']
# ['sons', 'NNS']
# ['shed', 'VBD']
# ['infants', 'NNS']
# ['#Augustine', 'NNP']
# ['#Psalm106', 'NNP']
# ['BRAVO', 'NNP']
# ['BEAUTIFULLY', 'NNP']
# ['EXPLAINED', 'NNP']
# ['HOLD', 'VB']
# ['#humantrafficking', 'NN']
# ['@SenBlumenthal', 'NNP']
# ['@DickDurbin', 'NNP']
# ['#womensrights', 'JJ']
# ['#righttochoose', 'NN']
# ['free', 'JJ']
# ['Freedom', 'NNP']
# ['includes', 'VBZ']
# ['Unthinkable', 'NNP']
# ['shameful', 'JJ']
# ['acceptable', 'JJ']
# ['encouraged', 'JJ']
# ['desirable', 'JJ']
# ['evolution', 'NN']
# ['defenseless', 'JJ']
# ['@msnbc', 'JJ']
# ['@jemimakirke', 'JJ']
# ['Lord', 'NNP']
# ['#TeamJesus', 'NNP']
# ['@AdamMyerson', 'NNP']
# ['@quarq', 'NNP']
# ['Sent', 'NNP']
# ['mine', 'NN']
# ['Expect', 'VB']
# ['Quick', 'NNP']
# ['turnaround', 'NN']
# ['customer', 'NN']
# ['service', 'NN']
# ['#IslamicState', 'NNP']
# ['murder', 'NN']
# ['dismemberment', 'NN']
# ['difference', 'NN']
# ['age', 'NN']
# ['victims', 'NNS']
# ['@DWStweets', 'NNPS']
# ['@RepDWStweets', 'NNPS']
# ['murderer', 'NN']
# ['bad', 'JJ']
# ["didn't", 'NN']
# ['operation', 'NN']
# ['#Baby', 'NNP']
# ['#Democrats', 'NNP']
# ['#Losers', 'NNPS']
# ['WH', 'NNP']
# ["Motherhood's", 'NNP']
# ['Wage', 'NN']
# ['pay', 'VBP']
# ['em', 'JJ']
# ["WTF's", 'NNS']
# ['point', 'VBP']
# ['libs', 'NNS']
# ['champion', 'NN']
# ['@BuckSexton', 'NNP']
# ['course', 'NN']
# ['Feds', 'NNS']
# ['puff', 'NN']
# ['pass', 'VB']
# ['#TeamBuck', 'NNP']
# ['#warondrugs', 'VBZ']
# ['i', 'NNS']
# ['past', 'JJ']
# ['aborted', 'JJ']
# ['union', 'NN']
# ['peripheral', 'JJ']
# ['@MsMistiNichole', 'NNP']
# ['think', 'VBP']
# ['Marcus', 'NNP']
# ['scared', 'VBN']
# ['radical', 'JJ']
# ['liberal', 'JJ']
# ['side', 'NN']
# ['set', 'VB']
# ['clinic', 'NN']
# ['fire', 'NN']
# ['join', 'VB']
# ['debate', 'NN']
# ['duty', 'NN']
# ['Ronald', 'NNP']
# ['#gop', 'NN']
# ['Bitches', 'NNPS']
# ['cockroach', 'NN']
# ['house', 'NN']
# ['quick', 'JJ']
# ['ironic', 'JJ']
# ['ppl', 'NN']
# ['perform', 'VB']
# ['lifesaving', 'JJ']
# ['therapies', 'NNS']
# ['animals', 'NNS']
# ['preserve', 'VB']
# ['lives-but', 'NN']
# ['staunch', 'JJ']
# ['views', 'NNS']
# ['favor', 'NN']
# ['@tonylee01979', 'NN']
# ["doesn't", 'JJ']
# ['harass', 'VB']
# ['Goodbye', 'NNP']
# ['#freedom', 'NN']
# ['gas', 'NN']
# ['increases', 'NNS']
# ['self-mutilation', 'NN']
# ['tattoos', 'NNS']
# ['piercing', 'VBG']
# ['drugging', 'VBG']
# ['over-eating', 'VBG']
# ['suicide', 'NN']
# ['violence', 'NN']
# ['#waleg', 'JJ']
# ['Took', 'NNP']
# ['discipline', 'NN']
# ['tobacco', 'NN']
# ['airtight', 'NN']
# ['filled', 'VBN']
# ['homes', 'NNS']
# ['w', 'VBD']
# ['CO2', 'NN']
# ['cuz', 'NN']
# ['energy', 'NN']
# ['climate', 'NN']
# ['lies', 'NNS']
# ['Evil', 'NNP']
# ['soared', 'VBD']
# ['deep-seated', 'JJ']
# ['cultural', 'JJ']
# ['codes', 'NNS']
# ['beliefs', 'NNS']
# ['structural', 'JJ']
# ['biases', 'NNS']
# ['changed', 'VBN']
# ['PlannedParentHood', 'NNP']
# ['agenda', 'NN']
# ['money', 'NN']
# ['big', 'JJ']
# ['business', 'NN']
# ['minority', 'NN']
# ['genocide', 'NN']
# ['result', 'NN']
# ['@NYS4Life', 'NNP']
# ['defeat', 'VB']
# ['#AssistedSuicidelike', 'JJ']
# ['defeated', 'VBD']
# ['#AbortionExpansion', 'NN']
# ['#noPASny', 'JJ']
# ['@Loriisright', 'NNP']
# ['@DWMcAliley1791', 'NNP']
# ['@LitaZahn', 'NNP']
# ['Yup', 'NNP']
# ['changed', 'VBD']
# ['parties', 'NNS']
# ['antichoice', 'JJ']
# ["people's", 'NNS']
# ['homophobic', 'JJ']
# ['Shocker', 'NN']
# ['poverty', 'NN']
# ['provide', 'VBP']
# ['killing', 'NN']
# ['sin', 'NN']
# ['#Quran', 'NNP']
# ['waiting', 'VBG']
# ['explain', 'VB']
# ['premeditated', 'JJ']
# ['@mrsdrjim', 'NN']
# ['did', 'VBD']
# ['#wrp', 'NN']
# ['@BrianJeanWRP', 'NNP']
# ['tried', 'VBD']
# ['personhood', 'NN']
# ['federal', 'JJ']
# ['im', 'NN']
# ['sitting', 'VBG']
# ['@PPact', 'NNP']
# ['swiping', 'VBG']
# ['@Tinder', 'NNP']
# ['chooses', 'VBZ']
# ['huge', 'JJ']
# ['#Adoption', 'NNP']
# ['@BruvverEccles', 'NNP']
# ['@Telegraph', 'NNP']
# ['@David_Cameron', 'NNP']
# ['despair', 'NN']
# ['grandchildren', 'NNS']
# ['luxury', 'NN']
# ['item', 'NN']
# ['@Snitfit', 'NNP']
# ["it's", 'VBZ']
# ['does', 'VBZ']
# ['effect', 'VB']
# ["it's", 'JJ']
# ['none', 'NN']
# ['Obamcare', 'NNP']
# ['loses', 'VBZ']
# ['Supreme', 'NNP']
# ['Court', 'NNP']
# ['win', 'VB']
# ['#scotus', 'JJ']
# ['#tcot', 'JJ']
# ['spoke', 'VBD']
# ['Nazis', 'NNPS']
# ['World', 'NNP']
# ['War', 'NNP']
# ['II', 'NNP']
# ['likely', 'JJ']
# ['let', 'VBP']
# ['live', 'JJ']
# ['#fb', 'JJ']
# ['Pro-choice', 'NNP']
# ['pro-murder', 'NN']
# ['couched', 'VBN']
# ['rhetoric', 'NN']
# ["ya'll", 'NN']
# ['push', 'VB']
# ['remain', 'VB']
# ['@ProWomanChoice', 'NNP']
# ['apologies', 'NNS']
# ['needed', 'VBN']
# ['#fundamentalist', 'JJ']
# ['kind', 'NN']
# ['#Hillary', 'NNP']
# ["Here's", 'NNP']
# ['Christian', 'JJ']
# ['religion', 'NN']
# ['adapt', 'VB']
# ['include', 'VB']
# ['respond', 'VB']
# ['frustrates', 'VBZ']
# ['steal', 'VB']
# ['#EasyWeightLoss', 'NNP']
# ['@NoMoreTeaForMe', 'NNP']
# ["weren't", 'VBP']
# ["he's", 'VBZ']
# ['coward', 'NN']
# ['#RepKevinCalvey', 'NNP']
# ['#LibCrib', 'NNP']
# ['#UniteBlue', 'NNP']
# ['upset', 'VBN']
# ['Black', 'NNP']
# ['Man', 'NNP']
# ['killed', 'VBD']
# ['knew', 'VBD']
# ['BlackKids', 'NNS']
# ['killed', 'VBN']
# ['#BaltimoreRiots', 'NNP']
# ['absurd', 'JJ']
# ['refer', 'VB']
# ['saves', 'VBZ']
# ['lives', 'NNS']
# ['@GolfProYYC', 'NNP']
# ['@TaylorMadeGolf', 'NNP']
# ['pops', 'VBZ']
# ['posting', 'VBG']
# ['#dyslexic', 'JJ']
# ['#oneinthesame', 'JJ']
# ['@beckaviau', 'JJ']
# ['@MikeRedmondNDP', 'NNP']
# ['duh', 'NN']
# ['election', 'NN']
# ['date', 'NN']
# ['fad', 'NN']
# ['times', 'NNS']
# ['pray', 'VBP']
# ['global', 'JJ']
# ['holocaust', 'NN']
# ['consider', 'VB']
# ['leaves', 'VBZ']
# ['patient', 'JJ']
# ['healthy', 'JJ']
# ['happy', 'JJ']
# ['@notmuchelse', 'VB']
# ['Rip', 'NNP']
# ['limb', 'NN']
# ['change', 'NN']
# ['subject', 'NN']
# ['Libertarian', 'NNP']
# ['@codeinediva', 'NN']
# ['i', 'NNP']
# ['weak', 'JJ']
# ['strong', 'JJ']
# ['#WeWillOvercome', 'NNP']
# ['@ProWomanChoice', 'JJ']
# ['forcing', 'VBG']
# ["body's", 'JJ']
# ['normal', 'JJ']
# ['function', 'NN']
# ['epitome', 'NN']
# ['controlling', 'VBG']
# ['govt', 'NN']
# ['taking', 'VBG']
# ['defunding', 'VBG']
# ['Watching', 'VBG']
# ['teen', 'JJ']
# ['Farrah', 'NNP']
# ['bitch', 'NN']
# ['@AMLiveNTV', 'NNP']
# ['sacred', 'JJ']
# ['giver', 'NN']
# ['onlyHim', 'NN']
# ['take', 'VB']
# ['@SteveStfler', 'NNP']
# ['brain', 'NN']
# ['unique', 'JJ']
# ['DNA', 'NN']
# ["mother's", 'NNS']
# ['Please', 'VB']
# ['Agree', 'NNP']
# ['danger', 'NN']
# ['father', 'NN']
# ['@HelpBillColeman', 'NNP']
# ['@LifeNewsHQ', 'NNP']
# ['happened', 'VBN']
# ['cruel', 'JJ']
# ['hard-hearted', 'JJ']
# ['#waronwomen', 'JJ']
# ['Joining', 'VBG']
# ['studio', 'NN']
# ['Amos', 'NNP']
# ['Josh', 'NNP']
# ['Music', 'NNP']
# ['Career', 'NNP']
# ['Kobi', 'NNP']
# ['Kihara', 'NNP']
# ['#Bands', 'NNPS']
# ['@giannaberettamo', 'NN']
# ['@GiaMolla', 'NNP']
# ['@sphcs_news', 'VBZ']
# ['feast', 'NN']
# ['St', 'NNP']
# ['Gianna', 'NNP']
# ['Beretta', 'NNP']
# ['Molla', 'NNP']
# ['May', 'NNP']
# ['onion', 'NN']
# ['one', 'NN']
# ['cries', 'VBZ']
# ['chop', 'VB']
# ['Hahahahaha', 'NNP']
# ['Love', 'NNP']
# ['#Babies', 'NNP']
# ['kingdom', 'NN']
# ['founded', 'VBN']
# ['vice', 'NN']
# ['brought', 'VBD']
# ['existence', 'NN']
# ['<', 'NNP']
# ['commentary', 'NN']
# ['Judges', 'NNP']
# ['@BarackObama', 'NNP']
# ['meaningless', 'JJ']
# ['stand', 'VBP']
# ['Kudos', 'NNP']
# ['mentality', 'NN']
# ['believes', 'VBZ']
# ['dumb', 'JJ']
# ['use', 'VB']
# ['protection', 'NN']
# ['mature', 'JJ']
# ['enough', 'NN']
# ['pray', 'NN']
# ['mercy', 'NN']
# ['#AndrewChan', 'NNP']
# ['#MyuranSukumaran', 'NNP']
# ['#IStandForMercy', 'NNP']
# ['#KeepHopeAlive', 'NNP']
# ['#Bali9', 'NNP']
# ['sit', 'VB']
# ['corner', 'NN']
# ['cry', 'NN']
# ['wish', 'VBP']
# ['thicker-skinned', 'JJ']
# ['feminist', 'NN']
# ['shit', 'NN']
# ['#MyBodyMyRights', 'NNP']
# ['@Fredindimuli', 'NNP']
# ['opinion', 'NN']
# ['hands', 'NNS']
# ['affected', 'VBN']
# ['Gov', 'NNP']
# ['Brownback', 'NNP']
# ['visits', 'VBZ']
# ['cities', 'NNS']
# ['#Kansas', 'NNP']
# ['sign', 'NN']
# ['#bill', 'NN']
# ['#woman', 'NN']
# ['praying', 'VBG']
# ['end', 'NN']
# ['@BBCNewshour', 'NNP']
# ['wife', 'NN']
# ['blow', 'VB']
# ['sound', 'NN']
# ['#ElSalvador', 'NNP']
# ['postinor', 'NN']
# ['used', 'VBN']
# ['mint', 'NN']
# ['Listening', 'VBG']
# ['@GlennBeck', 'NNP']
# ['LIVE', 'NNP']
# ['s', 'VBZ']
# ['talking', 'VBG']
# ['#MargaretSanger', 'NNP']
# ['total', 'JJ']
# ['#Abortion', 'JJ']
# ['@WayneSense', 'NN']
# ['check', 'NN']
# ['@ProLifeLiberty', 'NNP']
# ['reasoning', 'NN']
# ['horrible', 'JJ']
# ['Terrible', 'NNP']
# ['golf', 'NN']
# ['couple', 'NN']
# ['Goes', 'NNP']
# ['notes', 'NNS']
# ['Idiot', 'NNP']
# ['feel', 'VB']
# ['cause', 'NN']
# ['fucking', 'VBG']
# ['wks', 'NNS']
# ['late', 'JJ']
# ['termination', 'NN']
# ['triplets', 'NNS']
# ['cells', 'NNS']
# ['Dude', 'NNP']
# ['#freeshirt', 'NN']
# ['lol', 'NN']
# ['#Abort73', 'NNP']
# ["She's", 'VBZ']
# ['victim', 'NN']
# ['hope', 'VBP']
# ['execution', 'NN']
# ['proceed', 'VB']
# ['#NoToDeathPenalty', 'NNP']
# ['#SaveMaryJaneVeloso', 'NNP']
# ['Findin', 'NNP']
# ['budget', 'NN']
# ['compromise', 'NN']
# ['process', 'NN']
# ['#Brownback', 'NNP']
# ['says', 'VBZ']
# ['#income', 'JJ']
# ['#thestate', 'JJ']
# ['@AnneJp1946', 'NNP']
# ['control', 'NN']
# ['go', 'VBP']
# ['thing', 'NN']
# ['solution', 'NN']
# ['idea', 'NN']
# ['sinners', 'NNS']
# ['humans', 'NNS']
# ['wanted', 'VBD']
# ['#SCL', 'JJ']
# ['#thoughts', 'NNS']
# ['@politicspizza', 'NN']
# ['@RebeccahLouise', 'NNP']
# ['independent', 'JJ']
# ['CHOICES', 'NNP']
# ['responsible', 'JJ']
# ['@charulife', 'JJ']
# ['explained', 'VBD']
# ['helped', 'VBD']
# ['get', 'VBP']
# ['Medicaid', 'NNP']
# ['WIC', 'NNP']
# ['AB', 'NNP']
# ['passed', 'VBD']
# ['Committee', 'NNP']
# ['@WildChild69', 'NNP']
# ['limit', 'NN']
# ["doctor's", 'JJ']
# ['/', 'VB']
# ['w', 'JJ']
# ['dignity', 'NN']
# ['Meme', 'NNP']
# ['like', 'JJ']
# ['Reddit', 'NN']
# ['thread', 'NN']
# ['Earth', 'NNP']
# ['#AgeofUltron', 'NNP']
# ['#lifeadvice', 'JJ']
# ['#protip', 'NN']
# ['#propeller', 'NN']
# ['#propane', 'NN']
# ['#andpropaneaccessories', 'NNS']
# ['Typo', 'NNP']
# ['meant', 'VBD']
# ['dies', 'VBZ']
# ['@Singerman2000', 'NNP']
# ['Government', 'NNP']
# ['exceeded', 'VBN']
# ['necessary', 'JJ']
# ['size', 'NN']
# ['scope', 'NN']
# ['reach', 'VB']
# ['citizens', 'NNS']
# ['#Armenia', 'NNP']
# ['@rosaryrevival', 'JJ']
# ['Prayers', 'NNS']
# ['wishes', 'NNS']
# ['Catherine', 'NNP']
# ['Sienna', 'NNP']
# ['Wednesday', 'NNP']
# ['#Eastertide', 'NNP']
# ['Glorious', 'NNP']
# ['Mysteries', 'NNPS']
# ['usual', 'JJ']
# ['Inching', 'VBG']
# ['diabetes', 'NN']
# ['supporting', 'VBG']
# ['@ProChoiceMass', 'NNS']
# ['#ChocolateMadness', 'NNP']
# ['#mapoli', 'NNP']
# ['@alvedaking', 'NN']
# ['disturbing', 'JJ']
# ['planet', 'NN']
# ['flood', 'VB']
# ['streets', 'NNS']
# ['#blood', 'NN']
# ['#children', 'NNS']
# ['#HappyEarth', 'NNP']
# ['alvedaking', 'NN']
# ['#HappyEarthD', 'NNP']
# ['@PinkGypsySoul', 'NNP']
# ['single', 'JJ']
# ['important', 'JJ']
# ['factor', 'NN']
# ['advancement', 'NN']
# ['society', 'NN']
# ['ability', 'NN']
# ['fertility', 'NN']
# ['government', 'NN']
# ['words', 'NNS']
# ['bible', 'NN']
# ['bodies', 'NNS']
# ['@spicysandwich', 'NN']
# ['Anti-abortion', 'JJ']
# ['laws', 'NNS']
# ['lead', 'VB']
# ['unsafe', 'JJ']
# ['Preach', 'NNP']
# ['Sheriff', 'NNP']
# ["They'd", 'NNP']
# ['Protest', 'NNP']
# ['Clinics', 'NNP']
# ['#ChooseLIFE', 'NNP']
# ['@gvandersee', 'VB']
# ['estimated', 'JJ']
# ['ozzie', 'JJ']
# ['vulnerable', 'JJ']
# ['unwanted', 'JJ']
# ['unlife', 'JJ']
# ['Value', 'NNP']
# ['Respect', 'NN']
# ["aren't", 'VBP']
# ['unprotected', 'JJ']
# ['@AYoungJFK', 'NNP']
# ['Mark', 'NNP']
# ['#profeminist', 'JJ']
# ['riddance', 'NN']
# ['millions', 'NNS']
# ['black', 'JJ']
# ["I'm", 'JJ']
# ['@gbforchoice', 'JJ']
# ['#AbortionIsMurder', 'NN']
# ['#LiberalLogic', 'NNP']
# ['#reproductiverights', 'NNS']
# ['allow', 'VBP']
# ['families', 'NNS']
# ['escape', 'VB']
# ['#abvote', 'JJ']
# ['pro-choicer', 'NN']
# ['carry', 'VBP']
# ['logical', 'JJ']
# ['conclusion', 'NN']
# ['#faminism', 'NN']
# ['#YesAllWomen', 'NNP']
# ['@shaniaajaee', 'VB']
# ['matter', 'VB']
# ['@emrata', 'NNS']
# ['become', 'VB']
# ['lib', 'NN']
# ['Hollywood', 'NNP']
# ['#BlackLivesDontMatter', 'NNP']
# ['#whitebrunch', 'NN']
# ['Powerful', 'JJ']
# ['Blessed', 'JJ']
# ['@Stuart1927', 'NNP']
# ['@GoodCounselNet', 'NNP']
# ['goodness', 'NN']
# ['saw', 'VBD']
# ['recognised', 'JJ']
# ["women's", 'NNS']
# ['@RogerIsCatholic', 'NNP']
# ['Save', 'VB']
# ['Baby', 'NNP']
# ['Humans', 'NNPS']
# ['@DogsOfGod', 'NNP']
# ['fight', 'VB']
# ["Women's", 'NNP']
# ['joke', 'NN']
# ['Omg', 'VBG']
# ['Lol', 'NNP']
# ['#prolifegen', 'NN']
# ['abolish', 'VB']
# ['lifetime', 'NN']
# ['#prolifefuture', 'JJ']
# ['un-pregnant', 'JJ']
# ['mother', 'NN']
# ['isright', 'JJ']
# ['BABYS', 'NNP']
# ['yours', 'NNS']
# ['status', 'NN']
# ['preborn', 'JJ']
# ['girls', 'NNS']
# ['#peivotes', 'VBZ']
# ['@abc13houston', 'NN']
# ['Let', 'NNP']
# ['Obama', 'NNP']
# ['Control', 'NNP']
# ['Actions', 'NNS']
# ['destroyed', 'VBN']
# ['Community', 'NNP']
# ['#LBJ', 'NNP']
# ['#Clintons', 'NNP']
# ['#Drugs', 'NNPS']
# ['Pro-Life', 'NNP']
# ['Legislative', 'NNP']
# ['Day', 'NNP']
# ['Party', 'NNP']
# ['Lansing', 'NNP']
# ['#sopumpedgen', 'JJ']
# ["that's", 'NNS']
# ['#ycot', 'JJ']
# ['@Hannah_Warren14', 'NN']
# ['oppressive', 'JJ']
# ['generation', 'NN']
# ['ends', 'NNS']
# ['toes', 'NNS']
# ['step', 'NN']
# ['offend', 'VB']
# ['put', 'VB']
# ['@FrCharles', 'NNPS']
# ['believe', 'VB']
# ['narrative', 'NN']
# ['ALL', 'NNP']
# ['#BlackOnBlackViolence', 'NNP']
# ['@hillaryclinton', 'NN']
# ['guess', 'VBP']
# ['means', 'NNS']
# ["you're", 'VBP']
# ['#hypocrisy', 'NN']
# ['pro', 'JJ']
# ["can't", 'NN']
# ['ones', 'NNS']
# ["woman's", 'NNS']
# ['comes', 'VBZ']
# ["shouldn't", 'VBP']
# ['vote', 'VB']
# ['@reggielittlejhn', 'VB']
# ['speak', 'VB']
# ['leading', 'VBG']
# ['Frontiers', 'NNS']
# ['inspiring', 'JJ']
# ['@AUL', 'NNP']
# ['@JeanneaneMaxon', 'NNP']
# ['education', 'NN']
# ['Caring', 'VBG']
# ['Changing', 'VBG']
# ['cis-nomative', 'JJ']
# ['atmosphere', 'NN']
# ['difficult', 'JJ']
# ['stillborn', 'NN']
# ['loss', 'NN']
# ['@CrushTheCFR', 'NNP']
# ['heard', 'VBD']
# ['tweeted', 'VBD']
# ['provide', 'VB']
# ['demonstrated', 'VBN']
# ['training', 'NN']
# ['preparation', 'NN']
# ['COMING', 'NNP']
# ['WOMAN', 'NNP']
# ['#sexed', 'VBD']
# ['#marriage', 'JJ']
# ['#books', 'NNS']
# ['@EmilyBeaulieu1', 'NNP']
# ["that's", 'VBZ']
# ['knows', 'VBZ']
# ['@Niall250', 'NNP']
# ['#DUP', 'NNP']
# ['+', 'NNP']
# ['SF', 'NNP']
# ['meant', 'VBN']
# ['trigger', 'VB']
# ['emotional', 'JJ']
# ['responses', 'NNS']
# ['inaccuracies', 'NNS']
# ['misogyny', 'NN']
# ['adjudicating', 'VBG']
# ['systems', 'NNS']
# ['results', 'NNS']
# ['#Rape', 'NNP']
# ['@PPact', 'JJ']
# ['treating', 'VBG']
# ['kindness', 'NN']
# ['TLC', 'NNP']
# ['wellness', 'NN']
# ['exam', 'NN']
# ['#womenshealth', 'JJ']
# ['#yaycondoms', 'NNS']
# ['lot', 'NN']
# ['compassionate', 'JJ']
# ['tell', 'VBP']
# ['Bodily', 'NNP']
# ['autonomy', 'NN']
# ["person's", 'JJ']
# ['#reprojustice', 'NN']
# ['#reprorights', 'JJ']
# ['@charlescwcooke', 'JJ']
# ["they're", 'VB']
# ['Imagine', 'VB']
# ['getting', 'VBG']
# ['chance', 'NN']
# ['Re', 'NNP']
# ['providers', 'NNS']
# ['dismember', 'VB']
# ['sounds', 'VBZ']
# ['inhumane', 'JJ']
# ['Praise', 'NNP']
# ['District', 'NNP']
# ['Judge', 'NNP']
# ['Larry', 'NNP']
# ['Hendricks', 'NNP']
# ['Kansas', 'NNP']
# ['VAN', 'NN']
# ['action', 'NN']
# ['#datadatadata', 'JJ']
# ['@ScottWalker', 'NNP']
# ['goes', 'VBZ']
# ['Captors', 'NNPS']
# ['longer', 'JJR']
# ['part', 'NN']
# ['#choose', 'VB']
# ['Thats', 'VBZ']
# ['#lie', 'NN']
# ['#babies', 'NNS']
# ['#die', 'VB']
# ['Prolifeyouthgen', 'NNP']
# ['#yourbody', 'JJ']
# ['#choice', 'JJ']
# ['youthgen', 'JJ']
# ["#person's", 'JJ']
# ['value', 'NN']
# ['determined', 'VBN']
# ['#size', 'NN']
# ['#prolifegen', 'JJ']
# ['#prolifeyouth', 'JJ']
# ['formed', 'VBD']
# ['#womb', 'NN']
# ['#God', 'NNP']
# ['#smallest', 'JJS']
# ['#person', 'NN']
# ['#future', 'NN']
# ["one's", 'NNS']
# ['license', 'NN']
# ['Youth', 'NNP']
# ['#pregnant', 'JJ']
# ['heads', 'NNS']
# ['hearts', 'NNS']
# ['arms', 'NNS']
# ['legs', 'NNS']
# ['#didntthinkso', 'NN']
# ['#right', 'NN']
# ['#life', 'NN']
# ['#first', 'NN']
# ['#humanrights', 'NNS']
# ['Francisyouthgen', 'NNP']
# ['#God', 'JJ']
# ['#live', 'VB']
# ['places', 'NNS']
# ['#mother', 'NN']
# ['Phil', 'NNP']
# ['Robertsonyouthgen', 'NNP']
# ['#roevwade', 'JJ']
# ['#generation', 'NN']
# ['#aborted', 'VBN']
# ['#rights', 'NNS']
# ['#poverty', 'NN']
# ['decide', 'VB']
# ['#child', 'NN']
# ['#prolifeyouth', 'NN']
# ['saying', 'VBG']
# ['#flowers', 'NNS']
# ['Pretend', 'VB']
# ['#tree', 'NN']
# ['#save', 'VB']
# ['everywhereyouthgen', 'JJ']
# ['#human', 'JJ']
# ['@PPFA', 'NNP']
# ['youth', 'NN']
# ['#itisahumanlife', 'JJ']
# ['looking', 'VBG']
# ['other', 'JJ']
# ['#planets', 'NNS']
# ['#stop', 'VB']
# ['#killing', 'JJ']
# ['answer', 'NN']
# ['#crisis', 'NN']
# ['#pregnancy', 'NN']
# ['eliminate', 'VB']
# ['crisis', 'NN']
# ['brothers', 'NNS']
# ['Jesus', 'NNP']
# ['loves', 'VBZ']
# ['womb', 'NN']
# ['Legalized', 'NNP']
# ['tweeting-instead-of-procreating', 'NN']
# ['discriminates', 'VBZ']
# ['unconceived', 'JJ']
# ['#worstargumentever', 'JJ']
# ['#lolanti', 'NNS']
# ['Call', 'VB']
# ['#extremist', 'NN']
# ['#dismembering', 'VBG']
# ['others', 'NNS']
# ['prophets', 'NNS']
# ['@DardenMBA', 'NNP']
# ['former', 'JJ']
# ['oppose', 'VBP']
# ["haven't", 'VBP']
# ['eliminated', 'VBN']
# ['#name', 'NN']
# ['bit', 'NN']
# ["can't", 'JJ']
# ['hear', 'VB']
# ['Four', 'NNP']
# ['moreYouth', 'JJ']
# ['@kilcurry', 'VB']
# ['wealding', 'VBG']
# ['authority', 'NN']
# ['stop', 'NN']
# ['disobey', 'VB']
# ['cannot', 'VBP']
# ['conceive', 'VB']
# ['beg', 'VB']
# ['reconsider', 'VB']
# ['die', 'VB']
# ['liberty', 'NN']
# ['pursuit', 'NN']
# ["aren't", 'NN']
# ['possible', 'JJ']
# ['Canada', 'NNP']
# ['parts', 'NNS']
# ['USA', 'NNP']
# ['hospitals', 'NNS']
# ['signed', 'VBN']
# ['#voice', 'NN']
# ['#voiceless', 'JJ']
# ['Stand', 'VB']
# ['#unborn', 'NN']
# ['feel', 'VBP']
# ['qualified', 'VBN']
# ['#ThingsYouDontSayAsAPolitician', 'NNP']
# ['understanding', 'NN']
# ['/', 'NNS']
# ['member', 'NN']
# ['tho', 'VBP']
# ['tiny', 'JJ']
# ['powerless', 'JJ']
# ['Precisely', 'NNP']
# ["God's", 'NNP']
# ['eyes', 'NNS']
# ["Let's", 'NNP']
# ['ends', 'VBZ']
# ['@OurBrother1', 'NNP']
# ['kills', 'VBZ']
# ['future', 'NN']
# ['~', 'NNP']
# ['Bl', 'NNP']
# ['John', 'NNP']
# ['Paul', 'NNP']
# ['babiesyouthgen', 'JJ']
# ['Thr', 'NNP']
# ['r', 'NN']
# ['w', 'VBP']
# ['o', 'NN']
# ['responsibilities', 'NNS']
# ['rt', 'JJ']
# ['bodily', 'JJ']
# ['/', 'VBG']
# ['responsibility', 'NN']
# ['begins', 'VBZ']
# ["Men's", 'NNP']
# ['wrongs', 'VBZ']
# ['#Standforchoice', 'JJ']
# ['reading', 'VBG']
# ['tweet', 'NN']
# ['team', 'NN']
# ['Excited', 'VBN']
# ['expand', 'VB']
# ['Team', 'NNP']
# ['Sobhy', 'NNP']
# ['#silence', 'VB']
# ['message', 'NN']
# ['mock', 'JJ']
# ['#killing', 'VBG']
# ['mothers', 'NNS']
# ['granted', 'VBD']
# ['gift', 'NN']
# ["Canada's", 'NNP']
# ['definition', 'NN']
# ['based', 'VBN']
# ['th', 'JJ']
# ['century', 'NN']
# ['science', 'NN']
# ['update', 'NN']
# ['#cdnpoli', 'NNP']
# ['bacteria', 'NNS']
# ['considered', 'VBN']
# ['Mars', 'NNP']
# ['heartbeat', 'NN']
# ['earth', 'NN']
# ['#heartbeat', 'NN']
# ['@umich', 'JJ']
# ['Unjustified', 'NNP']
# ['homicide', 'NN']
# ['ALWAYS', 'NNP']
# ['including', 'VBG']
# ['valuable', 'JJ']
# ['waking', 'VBG']
# ['#ThingsYouDontSayAsAPolitician', 'NN']
# ['opposed', 'VBD']
# ['WRONG', 'VBG']
# ['Period', 'NN']
# ['@LogicOfLife7', 'NNP']
# ['confuse', 'VB']
# ["right-to-use-someone's-body-without-consent", 'JJ']
# ['@mikeboydprice', 'JJ']
# ['@Jake_Witmer', 'NNP']
# ["else's", 'NNS']
# ['advocating', 'VBG']
# ['punishment', 'NN']
# ['ppl', 'JJ']
# ['Premise', 'NNP']
# ["someone's", 'JJ']
# ['w', 'NN']
# ['/', 'NN']
# ['@UCBerkeley', 'NNP']
# ['Such', 'JJ']
# ['Unforced', 'NNP']
# ['Ireland', 'NNP']
# ['constitutional', 'JJ']
# ['Long', 'NNP']
# ['continued', 'JJ']
# ['chill', 'NN']
# ["we're", 'NN']
# ['dang', 'VBG']
# ['proud', 'JJ']
# ['injustices', 'NNS']
# ['treated', 'VBN']
# ['feminist', 'JJ']
# ['fighting', 'VBG']
# ['@kfadich', 'VB']
# ['sperm', 'NN']
# ['entitled', 'VBN']
# ['#worstargumentever', 'NN']
# ['hope', 'NN']
# ['Saint', 'NNP']
# ['missing', 'VBG']
# ['causes', 'NNS']
# ['circumstances', 'NNS']
# ['pregnancies', 'NNS']
# ['vary', 'VBP']
# ['unwavering', 'VBG']
# ['@bethanyshondark', 'JJ']
# ['Bristol', 'NNP']
# ['honest', 'JJ']
# ['feelings', 'NNS']
# ['relate', 'VB']
# ['choose', 'VBP']
# ['@prolife_wife', 'JJ']
# ['outside', 'JJ']
# ['Level', 'NNP']
# ['development', 'NN']
# ['Environment', 'NNP']
# ['Degree', 'NNP']
# ['dependency', 'NN']
# ['affect', 'VB']
# ["human's", 'JJ']
# ['#Abstinence', 'NNP']
# ['proponent', 'NN']
# ['#BristolPalin', 'NNP']
# ['second', 'JJ']
# ['conceives', 'VBZ']
# ['#humility', 'NN']
# ['#MirthControl', 'NNP']
# ['#BirthControl', 'NNP']
# ['@CandiesOrg', 'NNP']
# ['Oops', 'NNP']
# ['Candies', 'NNS']
# ['waste', 'NN']
# ['paid', 'VBD']
# ['PPL', 'NNP']
# ['Send', 'VB']
# ['darlings', 'NNS']
# ['advice', 'NN']
# ['abortionist', 'NN']
# ['unfinished', 'JJ']
# ['stories', 'NNS']
# ['#Writing', 'VBG']
# ['#Literary', 'NNP']
# ['Palin', 'NNP']
# ["doesn't", 'NN']
# ['lectures', 'VBZ']
# ["That's", 'NNP']
# ['#15minutes', 'VBZ']
# ['plan', 'NN']
# ["here's", 'VBZ']
# ['@Esmerald_Kiczek', 'NNP']
# ['fuck', 'VBP']
# ["I'm", 'NN']
# ['Cursed', 'JJ']
# ['takes', 'VBZ']
# ['bribe', 'NN']
# ['shed', 'VB']
# ['Deuteronomy', 'NNP']
# ['#dropsmic', 'JJ']
# ['@saadoescatholic', 'NN']
# ['#Americans', 'NNS']
# ['#life', 'JJ']
# ['#liberty', 'NN']
# ['#pursuitofhappiness', 'NN']
# ['dont', 'JJ']
# ['#unborn', 'JJ']
# ['Americans', 'NNS']
# ['Messed', 'JJ']
# ['outraged', 'VBN']
# ['distribute', 'VB']
# ['images', 'NNS']
# ['fine', 'NN']
# ['#No2Trudeau', 'NNP']
# ['C', 'NNP']
# ['offended', 'JJ']
# ['flag', 'NN']
# ['symbol', 'NN']
# ['deaths', 'NNS']
# ['#flag', 'VBG']
# ['#Mississippi', 'NNP']
# ['#blacks', 'NNS']
# ['#slavery', 'NN']
# ['#ConfederateFlag', 'NNP']
# ['STOP', 'NNP']
# ['called', 'VBD']
# ['leave', 'VB']
# ['quit', 'VBP']
# ['whining', 'VBG']
# ['forget', 'VB']
# ["we're", 'JJ']
# ['gone', 'VBN']
# ['#Reagan', 'NNP']
# ['#2A', 'NNP']
# ['#DogLover', 'NNP']
# ['#Conservative', 'NNP']
# ['@dave_gosh', 'NN']
# ['Im', 'NNP']
# ['Prolife', 'NNP']
# ['#Christians', 'NNS']
# ['#Prolife', 'NNP']
# ['Fact', 'NNP']
# ['sigh', 'NN']
# ['yawn', 'NN']
# ['#LifeFact', 'NNP']
# ['Christian', 'NNP']
# ['unworthy', 'JJ']
# ['#RedState', 'JJ']
# ['heat', 'NN']
# ['watch', 'NN']
# ['catch', 'VB']
# ['@TJBballCamp', 'NNP']
# ['basketball', 'NN']
# ['camp', 'NN']
# ['#work', 'JJ']
# ['#youthbuilding', 'JJ']
# ['speechless', 'JJ']
# ['rage', 'NN']
# ['hurt', 'VBN']
# ['complete', 'JJ']
# ['disgust', 'NN']
# ['Finding', 'VBG']
# ['V', 'NNP']
# ['hard', 'JJ']
# ['tongue', 'NN']
# ['@AnnaLoMLA', 'NNP']
# ['direction', 'NN']
# ['@BristolsBlog', 'NN']
# ['thank', 'VBP']
# ['loving', 'JJ']
# ['preaching', 'VBG']
# ['Undergirding', 'VBG']
# ['#racism', 'NN']
# ['#gender', 'NN']
# ['Good', 'NNP']
# ['Friday', 'NNP']
# ['#patriots', 'NNS']
# ['Make', 'VBP']
# ['ur', 'VBP']
# ['#Smile', 'NNP']
# ['#LNYHBT', 'NNP']
# ['#RescuePets', 'NNP']
# ['#SOT', 'NNP']
# ['#SOV', 'NNP']
# ['#NeverGiveUp', 'NNP']
# ['#SCOTUS', 'NNP']
# ["homosex'lity-based", 'JJ']
# ['carries', 'VBZ']
# ['moral', 'JJ']
# ['Roe', 'NNP']
# ['Wade', 'NNP']
# ['#Anti-Truth', 'NNP']
# ['deemed', 'VBD']
# ['defend', 'VB']
# ['ruling', 'NN']
# ['SCOTUS', 'NNP']
# ['#SCOTUSMarriage', 'NNP']
# ['#FreedomOfReligion', 'NNP']
# ['Woe', 'NNP']
# ['call', 'VBP']
# ['evil', 'JJ']
# ['evil', 'NN']
# ['Isaiah', 'NNP']
# ['advising', 'VBG']
# ["daughter's", 'NNS']
# ['insane', 'JJ']
# ['unacceptable', 'JJ']
# ['#Condoms', 'NNP']
# ['#ItsNotOnItsNotSafe', 'NNP']
# ['America', 'NNP']
# ['married', 'VBN']
# ['#MarriageEquaility', 'NNP']
# ['bless', 'VB']
# ['continues', 'VBZ']
# ['approve', 'VB']
# ['glorify', 'VB']
# ['things', 'NNS']
# ['opposition', 'NN']
# ['#SSM', 'NNP']
# ['@BristolsBlog', 'NNP']
# ['wedlock', 'JJ']
# ['lecture', 'NN']
# ['STUNNNG', 'NN']
# ['@LifeMattersJrnl', 'NNP']
# ['daughter', 'NN']
# ['@StMotherTheresa', 'NNP']
# ['destroys', 'VBZ']
# ['motherhood', 'NN']
# ['#motherteresa', 'NN']
# ['focus', 'VB']
# ['abolishing', 'VBG']
# ['stoping', 'VBG']
# ['murders', 'NNS']
# ['Alaska', 'NNP']
# ['asked', 'VBD']
# ['promote', 'VB']
# ['wide', 'JJ']
# ['open', 'JJ']
# ['spaces', 'NNS']
# ['state', 'NN']
# ['note', 'NN']
# ['smtg', 'VBG']
# ['mean', 'JJ']
# ['everyone', 'NN']
# ['accd', 'VBN']
# ['^', 'NNP']
# ['Woah', 'NNP']
# ['hashtag', 'NN']
# ['puts', 'VBZ']
# ['rainbow', 'NN']
# ['#butimnotgay', 'JJ']
# ['comply', 'VB']
# ['forced', 'VBD']
# ['force', 'VBP']
# ['owned', 'VBN']
# ['works', 'VBZ']
# ['planned', 'JJ']
# ['parenthood', 'NN']
# ['#factsonly', 'JJ']
# ['calling', 'VBG']
# ['embryos', 'NNS']
# ['fetuses', 'NNS']
# ['@_hannahwilhoit', 'JJ']
# ['done', 'VBN']
# ['convo', 'NN']
# ['Ok', 'NN']
# ['handle', 'VB']
# ['@WhiteHouse', 'NNP']
# ['@POTUS', 'NNP']
# ['#everylifematters', 'NNS']
# ['see', 'VBP']
# ['#POTUS', 'NNP']
# ['#Tyranny', 'NNP']
# ['#ArticleV', 'NNP']
# ['#FederalistPapers', 'NNP']
# ['#SCOTUScare', 'NNP']
# ['#GayMarriage', 'NNP']
# ['cry', 'VBP']
# ['dog', 'NN']
# ['movie', 'NN']
# ['seem', 'VBP']
# ['phase', 'VB']
# ['die', 'VBP']
# ['@GregAbbott_TX', 'NNP']
# ['define', 'VB']
# ['bigot', 'NN']
# ['trying', 'VBG']
# ['stick', 'VB']
# ['closed-minded', 'JJ']
# ['#bigot', 'JJ']
# ['brilliant', 'JJ']
# ['#lovewins', 'NNS']
# ['extend', 'VB']
# ['equality', 'NN']
# ['#abortionrights', 'JJ']
# ['#EVERYLIFEMATTERS', 'NNP']
# ['#gay', 'JJ']
# ['#straight', 'NN']
# ['#baby', 'NN']
# ['#precious', 'JJ']
# ['fathers', 'NNS']
# ['sanctity', 'NN']
# ['Human', 'NNP']
# ['Think', 'VB']
# ["won't", 'VBP']
# ['#adamandevenotadamandsteve', 'JJ']
# ['LGBT', 'NNP']
# ['community', 'NN']
# ['received', 'VBD']
# ['matters', 'VBZ']
# ['color', 'NN']
# ['rightful', 'JJ']
# ['Selfish', 'JJ']
# ['#BirthControlHelpedMe', 'NNP']
# ['cheat', 'VB']
# ['found', 'VBD']
# ['kill', 'VBP']
# ['@SuePalmers', 'NNP']
# ['@LSDsr', 'NNP']
# ['yours', 'VBZ']
# ['dictate', 'VB']
# ['#feminism', 'NN']
# ['Alright', 'NNP']
# ['next', 'JJ']
# ['order', 'NN']
# ['overturning', 'VBG']
# ['same-sex', 'JJ']
# ['@TheReadClub', 'NNP']
# ['wears', 'VBZ']
# ['#TheReadClub', 'NNP']
# ['@MeghanMcCain', 'NNP']
# ['ruled', 'VBD']
# ['fors', 'NNS']
# ['threw', 'VBD']
# ['supported', 'VBD']
# ['#LoveWins', 'NNP']
# ['reminder', 'NN']
# ['granted', 'VBN']
# ['opportunity', 'NN']
# ['share', 'VB']
# ['air', 'NN']
# ['breath', 'NN']
# ['#Equality', 'NNP']
# ['Complications', 'NNS']
# ['come', 'VBN']
# ['types', 'NNS']
# ['procedures', 'NNS']
# ['banned', 'VBN']
# ['#DealWithIt', 'NNP']
# ['#bristolpalin', 'NN']
# ['proof', 'NN']
# ['#abstinence', 'NN']
# ['Affordable', 'NNP']
# ['asshat', 'JJ']
# ['protesting', 'VBG']
# ['@SofiaVergara', 'NNP']
# ['disgrace', 'NN']
# ['entire', 'JJ']
# ['movement', 'NN']
# ['#SofiaVergara', 'NNP']
# ['Rights', 'NNPS']
# ['@abelitomiranda', 'NNS']
# ['Lets', 'VBZ']
# ['fix', 'VB']
# ['@Scullybones027', 'NNP']
# ['@AmnestyIreland', 'NNP']
# ['seen', 'VBN']
# ['declaring', 'VBG']
# ['protecting', 'VBG']
# ['#Murder', 'NNP']
# ['outsmart', 'VB']
# ['#satan', 'NN']
# ['thousands', 'NNS']
# ['#isis', 'NNS']
# ['@ErikLoomis', 'NNP']
# ["You're", 'NNP']
# ['historian', 'NN']
# ['malice', 'NN']
# ['hatred', 'NN']
# ['astonishing', 'JJ']
# ['#palin', 'JJ']
# ['@SCOTUS', 'NNP']
# ['#overturnRoe', 'JJ']
# ['@ArkBuilder17', 'NNP']
# ['disagree', 'VB']
# ['man', 'VB']
# ['proverbial', 'JJ']
# ['straw', 'NN']
# ['broke', 'VBD']
# ['back', 'NN']
# ["We've", 'NN']
# ['Abstinence', 'NNP']
# ['spokesmodel', 'NN']
# ['brawler', 'NN']
# ['Poor', 'NNP']
# ['rich', 'JJ']
# ['girl', 'NN']
# ['#Hypocrite', 'NNP']
# ['#Equality', 'JJ']
# ['ALL', 'NN']
# ['long', 'JJ']
# ['ending', 'VBG']
# ['won', 'VBN']
# [':)', 'JJ']
# ['deserves', 'VBZ']
# ['marry', 'VB']
# ['#EqualityForAll', 'NNP']
# ['@TheHeavySquad', 'NNP']
# ['#DailyWordsOfWisdom', 'NNP']
# ["Pat's", 'NNP']
# ['Hell', 'NNP']
# ['defines', 'VBZ']
# ['goverment', 'NN']
# ['#fostercare', 'JJ']
# ['#adoption', 'NN']
# ['Equality', 'NNP']
# ['states', 'NNS']
# ['nice', 'JJ']
# ['better', 'JJR']
# ['#ProudToLove', 'NNP']
# ['@rxchelredekop', 'NN']
# ['Consenting', 'VBG']
# ['disagrees', 'VBZ']
# ['mind', 'VB']
# ['damn', 'JJ']
# ['Conservatives', 'NNPS']
# ['#ksleg', 'VBG']
# ['@govsambrownback', 'NN']
# ['courts', 'NNS']
# ['#schoolfunding', 'JJ']
# ['#sweep', 'NN']
# ["there's", 'JJ']
# ['start', 'VB']
# ['working', 'VBG']
# ['@web_rant', 'JJ']
# ['shows', 'VBZ']
# ['liberals', 'NNS']
# ['thinking', 'VBG']
# ['consequences', 'NNS']
# ['#gaymarriage', 'JJ']
# ["I'll", 'NNP']
# ['focus', 'NN']
# ['gets', 'VBZ']
# ['celebrates', 'VBZ']
# ['talk', 'NN']
# ['real', 'JJ']
# ['inequality', 'NN']
# ['sir', 'NN']
# ['#LifeEquality', 'NNP']
# ['unfortunate', 'JJ']
# ['#thebriefcase', 'NN']
# ['@cbs', 'NNS']
# ["isn't", 'NN']
# ['Supremes', 'NNPS']
# ['saved', 'VBN']
# ['gays', 'NNS']
# ['aim', 'NN']
# ['forgotten', 'VBN']
# ['smallest', 'JJS']
# ['grow', 'VB']
# ['celebration', 'NN']
# ['dancing', 'VBG']
# ['butts', 'NNS']
# ['LGBTQIA', 'NNP']
# ['pride', 'NN']
# ['inspired', 'VBD']
# ['playlist', 'NN']
# ['songs', 'NNS']
# ['add', 'VB']
# ['list', 'NN']
# ['@conspiracyimage', 'JJ']
# ['@ThislsAmazing', 'JJ']
# ['noone', 'NN']
# ['@slowdoghdfc', 'JJ']
# ['mocked', 'VBN']
# ['tho', 'NN']
# ['blv', 'JJ']
# ['shd', 'VBD']
# ['judgment', 'NN']
# ['~', 'NNS']
# ['thr', 'JJ']
# ['wr', 'NN']
# ['enuf', 'JJ']
# ['rzn', 'NN']
# ['judge', 'NN']
# ['@michaelianblack', 'JJ']
# ['news', 'NN']
# ['allows', 'VBZ']
# ['#reprohealth', 'NN']
# ['#ReproJustice', 'JJ']
# ['nah', 'NN']
# ['@Caleb_Lopez760', 'NNP']
# ['bro', 'NN']
# ['@CaitlynGuyerXOX', 'NNP']
# ['Next', 'NNP']
# ['weekend', 'NN']
# ['Forced', 'NNP']
# ['reproduction', 'NN']
# ['violation', 'NN']
# ['planted', 'VBD']
# ['garden', 'NN']
# ['pull', 'VB']
# ['plants', 'NNS']
# ['bear', 'VB']
# ['fruit', 'NN']
# ['WORLDWIDE', 'NNP']
# ['R', 'NNP']
# ['E', 'NN']
# ['Agents', 'NNPS']
# ['Support', 'NN']
# ['Group', 'NNP']
# ['U-choose', 'NNP']
# ['NoCost', 'NNP']
# ['ProLifeRealEstate', 'NNP']
# ['@Yahoo', 'NNP']
# ['com', 'NN']
# ['destroyer', 'NN']
# ['peace', 'NN']
# ['@j6fras', 'NNS']
# ['got', 'VBD']
# ['hated', 'VBN']
# ['#progod', 'JJ']
# ['#progun', 'JJ']
# ['#Humans', 'NNPS']
# ['taken', 'VBN']
# ['role', 'NN']
# ['#RachelDolezal', 'NNP']
# ['#CaitlynJenner', 'NNP']
# ['#clinic', 'NN']
# ['chase', 'VB']
# ['anti-choice', 'JJ']
# ['nutters', 'NNS']
# ['harassing', 'VBG']
# ['patients', 'NNS']
# ['@Catniptwoshoes', 'NNP']
# ['@hoursofChaos', 'VBZ']
# ['@bindelj', 'VBN']
# ['#BackOff', 'NNP']
# ['lifeboatcoffee', 'JJ']
# ['SB', 'NNP']
# ['companies', 'NNS']
# ['left', 'NN']
# ['#1M1W', 'NNP']
# ['#SoProLife', 'NNP']
# ['Texans', 'NNPS']
# ['carry', 'VB']
# ["WON'T", 'NNP']
# ['EVEN', 'NNP']
# ['PRODUCE', 'NNP']
# ['HOW', 'NNP']
# ['COULD', 'NNP']
# ['BEFORE', 'JJR']
# ['BORN', 'NNP']
# ['TINY', 'NNP']
# ['LITTLE', 'NNP']
# ['THING', 'NNP']
# ["DOESN'T", 'NNP']
# ['MATTER', 'NNP']
# ['Manipulation', 'NNP']
# ['Disguise', 'NNP']
# ['out-come', 'NN']
# ['Ugly', 'NNP']
# ['Doors', 'NNPS']
# ['Satan', 'NNP']
# ['appear', 'VBP']
# ['forms', 'NNS']
# ['Fake', 'NNP']
# ['@ORConservative', 'NNP']
# ['@Pontifex', 'NNP']
# ['#SaveTheBabiesBumpThemAnimals', 'NNPS']
# ['#GodIsLoveSoLoveWins', 'NNP']
# ['moment', 'NN']
# ['intergenerational', 'JJ']
# ['dialogue', 'NN']
# ['RBG', 'NNP']
# ['brings', 'VBZ']
# ['@irin', 'NN']
# ['@AspenInstitute', 'NNP']
# ['Spotlight', 'NNP']
# ['Health', 'NNP']
# ['deny', 'VB']
# ['#LifeWins', 'NNP']
# ['#EndTheDiscrimination', 'NNP']
# ['focusing', 'VBG']
# ['#Immigration', 'NNP']
# ['#ChiefsKingdom', 'NNP']
# ['injustice', 'NN']
# ['known', 'VBN']
# ['abolished', 'VBN']
# ['Bigger', 'JJR']
# ['#worldhunger', 'NN']
# ['#cleanwater', 'NN']
# ['#sextrafficking', 'NN']
# ['#slavelabor', 'JJ']
# ['#thelost', 'NN']
# ["You'll", 'NNP']
# ['account', 'NN']
# ['Creator', 'NNP']
# ['slogan', 'NN']
# ['glad', 'JJ']
# ['Home', 'NN']
# ['#NMH', 'NNP']
# ['#ACA', 'NNP']
# ['notice', 'VB']
# ['Cruz', 'NNP']
# ['Constitution', 'NNP']
# ['Great', 'NNP']
# ['college', 'NN']
# ['Stevens', 'NNP']
# ['Point', 'NNP']
# ['gen', 'NN']
# ['#WRTLCollege', 'NNP']
# ["There's", 'NNP']
# ['undeniable', 'JJ']
# ['inverse', 'JJ']
# ['correlation', 'NN']
# ['rates', 'NNS']
# ['issues', 'NNS']
# ['#starvingchildren', 'NNS']
# ['#abuse', 'VBP']
# ['#nationaldebt', 'JJ']
# ['#terrorism', 'NN']
# ['Gay', 'NNP']
# ['Marriage', 'NNP']
# ['Murdering', 'VBG']
# ['GODS', 'NNP']
# ['#jesus', 'NNS']
# ['#bible', 'JJ']
# ['#EqualityForTheUnborn', 'NNP']
# ['@nytimes', 'NNS']
# ['anti-choicers', 'NNS']
# ['dealing', 'VBG']
# ['face', 'VB']
# ['prosecution', 'NN']
# ['abort', 'VBP']
# ['abort', 'JJ']
# ['generations', 'NNS']
# ['history', 'NN']
# ['healers', 'NNS']
# ['inventors', 'NNS']
# ['artists', 'NNS']
# ['husband', 'NN']
# ['Spent', 'NNP']
# ['WHOLE', 'NNP']
# ['highlight', 'NN']
# ['film', 'NN']
# ['Israel', 'NNP']
# ['trip', 'NN']
# ['post', 'VB']
# ['link', 'NN']
# ['Instagram', 'NNP']
# ['#ballislife', 'JJ']
# ["wasn't", 'VBP']
# ['favorite', 'JJ']
# ['characters', 'NNS']
# ['@CrimsonHotMess', 'NNP']
# ['input', 'NN']
# ['#womanschoice', 'JJ']
# ['#controlyourownbody', 'JJ']
# ['#America', 'NNP']
# ['#violence', 'NN']
# ['#samesex', 'NN']
# ['#LustWins', 'VBZ']
# ['#populationcontrol', 'JJ']
# ['#hate', 'JJ']
# ['#atheism', 'NN']
# ['#Secularism', 'NNP']
# ['@Jeffrey_Addison', 'NNP']
# ['@VolvoCarsAus', 'NNP']
# ['safety', 'NN']
# ['#auspol', 'JJ']
# ['@AdvocatesOfLife', 'NNP']
# ["shouldn't", 'NN']
# ['cost', 'NN']
# ['#adoptionclini', 'NNS']
# ['bday', 'JJ']
# ['bio', 'NN']
# ['parents', 'NNS']
# ['#nochoiceisevereasy', 'JJ']
# ['cannibalism', 'NN']
# ['comparing', 'VBG']
# ['eggs', 'NNS']
# ['chicken', 'NN']
# ['#cannibalism', 'NN']
# ['#analogy', 'NN']
# ['Gods', 'NNS']
# ['#Law', 'NNP']
# ['#supressed', 'VBN']
# ['eternal', 'JJ']
# ['#healthcare', 'NN']
# ['accept', 'VB']
# ['mankind', 'NN']
# ['#followthrough', 'JJ']
# ['#roevwade', 'NN']
# ['#science', 'NN']
# ['Girls', 'NNP']
# ['boys', 'NNS']
# ['Mzwakhe', 'NNP']
# ['mbuli', 'NNS']
# ['nurses', 'NNS']
# ['paid', 'VBN']
# ['assassins', 'NNS']
# ['fancy', 'JJ']
# ['name', 'NN']
# ["they're", 'NN']
# ['pro-birth', 'NN']
# ['happens', 'VBZ']
# ['race', 'NN']
# ['behave', 'VB']
# ['undignified', 'JJ']
# ['gain', 'VB']
# ['attention', 'NN']
# ['#furgison', 'NN']
# ['#prideparade', 'NN']
# ['#potus', 'NN']
# ['#isis', 'VBZ']
# ['#lgbt', 'JJ']
# ['living', 'VBG']
# ['remember', 'VB']
# ['#adopt', 'VB']
# ['@forrest_grump', 'JJ']
# ['Large', 'JJ']
# ['write', 'VB']
# ['imagine', 'VBP']
# ['read', 'VB']
# ['fucking', 'NN']
# ['leftists', 'NNS']
# ['doing', 'VBG']
# ['#tcot', 'NN']
# ['#LGBT', 'NNP']
# ['inestimable', 'JJ']
# ['worth', 'NN']
# ['created', 'VBN']
# ['image', 'NN']
# ['likeness', 'NN']
# ['JPII', 'NNP']
# ['@AnnieJMJ', 'NNP']
# ['@binghamrk', 'NN']
# ['trust', 'VB']
# ['trust', 'NN']
# ['guns', 'NNS']
# ['opposed', 'VBN']
# ['#liberallogic', 'NN']
# ['@SaculSacul', 'NNP']
# ['@GVPrayerWarrior', 'NNP']
# ['guarantee', 'VBP']
# ['hate', 'VBP']
# ['disagree', 'VBP']
# ['#SacramentofMatrimonyisSacred', 'NNP']
# ['cell', 'NN']
# ['division', 'NN']
# ['#ProtectLife', 'JJ']
# ['#pjnet', 'JJ']
# ['#ctot', 'NN']
# ['#ccot', 'NN']
# ['passed', 'VBN']
# ['defy', 'VBP']
# ['suffer', 'VBP']
# ['#promarriage', 'JJ']
# ['charity', 'NN']
# ['#LaudatoSi', 'NNP']
# ['@AUL', 'NN']
# ['tells', 'VBZ']
# ['MLK', 'NNP']
# ['#prolife', 'JJ']
# ['lying', 'VBG']
# ['gullible', 'JJ']
# ['followers', 'NNS']
# ['misinformed', 'JJ']
# ['@rob_mcarthur', 'NN']
# ['try', 'VBP']
# ['slaughtered', 'VBN']
# ['robbed', 'VBN']
# ['@modernwerewolf', 'NN']
# ['congratulate', 'VB']
# ['NOT', 'NNP']
# ['knocked', 'VBD']
# ['Throw', 'VB']
# ['shower', 'VB']
# ['#ReproJustice', 'NNP']
# ['Time', 'NNP']
# ['boxing', 'JJ']
# ['style', 'NN']
# ['@GGGBoxing', 'VBG']
# ['defense', 'NN']
# ['#beastmode', 'NN']
# ['#boxing', 'VBG']
# ['#ximenez', 'NN']
# ['surprised', 'VBN']
# ["Isn't", 'NNP']
# ['agency', 'NN']
# ['legalized', 'JJ']
# ['Wins', 'NNP']
# ["didn't", 'JJS']
# ['@NYCanegirl', 'NNP']
# ['premeditated', 'VBD']
# ['st', 'JJ']
# ['degree', 'NN']
# ['@PnkGlitterChemE', 'NNP']
# ['@SayNoToSuicide4', 'NNP']
# ['#Gay', 'NNP']
# ['#Choice', 'NN']
# ['gates', 'NNS']
# ['prevail', 'VB']
# ['Yo', 'NNP']
# ['decide', 'VBP']
# ['@nice_euna', 'NN']
# ['commandments', 'NNS']
# ['Thy', 'NNP']
# ['left', 'VBN']
# ['teachers', 'NNS']
# ['skills', 'NNS']
# ['Peer', 'NNP']
# ['Lay', 'VB']
# ['facts', 'NNS']
# ['misleading', 'JJ']
# ['@madisonfletch_', 'NNS']
# ['yo', 'VB']
# ['hand', 'NN']
# ['smells', 'VBZ']
# ['dick', 'JJ']
# ['notion', 'NN']
# ['ts', 'NNS']
# ['st', 'JJS']
# ['@LadySandersfarm', 'JJ']
# ['love', 'VB']
# ['terms', 'NNS']
# ['Anchor', 'NNP']
# ['storm', 'NN']
# ['Hebrews', 'NNP']
# ['@SenTedCruz', 'NNP']
# ['@TODAYshow', 'NNP']
# ['#Scotus', 'NNS']
# ['number', 'NN']
# ['Hitler', 'NNP']
# ["Hadn't", 'NNP']
# ['October', 'NNP']
# ['crying', 'VBG']
# ['thru', 'NN']
# ['movies', 'NNS']
# ...
# ['prevented', 'VBD']
# ['biggest', 'JJS']
# ['spree', 'NN']
# ['predicted', 'VBD']
# ['S', 'NNP']
# ['criminals', 'NNS']
# ["weren't", 'NN']
# ['#gunsense', 'JJ']
# ['dispersal', 'JJ']
# ['chemical', 'NN']
# ['weapon', 'NN']
# ['@JohnFugelsang', 'NNP']
# ['surprised', 'VBD']
# ['civilized', 'JJ']
# ['countries', 'NNS']
# ['@ChadCottle', 'NN']
# ['yr', 'NN']
# ['ONLY', 'NNP']
# ['decline', 'VB']
# ['criminal', 'JJ']
# ['Pregnancy', 'NNP']
# ['@Andrea_provida', 'NNP']
# ['hypocrisy', 'NN']
# ['campaign', 'NN']
# ['animal', 'JJ']
# ['Justice', 'NNP']
# ['Breyer', 'NNP']
# ['al', 'JJ']
# ['injections', 'NNS']
# ['killers', 'NNS']
# ['heinous', 'JJ']
# ['word', 'NN']
# ['acidic', 'JJ']
# ['saline', 'NN']
# ['executing', 'VBG']
# ['@CoraSherlock', 'NNP']
# ['@NORTHANNE', 'NNP']
# ['@fdelond', 'VBD']
# ['ignore', 'VB']
# ['IRE', 'NNP']
# ['export', 'VB']
# ['UK', 'NNP']
# ['@MarieStopes', 'NNP']
# ['#itwontgoaway', 'JJ']
# ['#repealthe8th', 'JJ']
# ['Bernadette', 'NNP']
# ['Smyth', 'NNP']
# ['ignorant', 'JJ']
# ['thunder', 'NN']
# ['cunt', 'NN']
# ['#ItsABallOfCellsNotABaby', 'NNP']
# ['#NewsNI', 'NNP']
# ['decided', 'VBD']
# ['realize', 'VB']
# ['conceded', 'VBD']
# ['Shaw', 'NNP']
# ['haggle', 'VB']
# ['#Idiots', 'NNP']
# ['#SignsYoureInTheUSA', 'NNP']
# ['Doc', 'NNP']
# ['knife', 'NN']
# ['Tyrant', 'NNP']
# ['#tgdn', 'JJ']
# ['Blocks', 'NNS']
# ['enforcing', 'VBG']
# ['designed', 'VBN']
# ['harder', 'JJR']
# ['#SupremeCourt', 'NNP']
# ['roll', 'NN']
# ['week', 'NN']
# ['discover', 'VBP']
# ['#coffee', 'NN']
# ['@SCOTUSblog', 'NNP']
# ['My', 'NNP']
# ['@TheGoodGodAbove', 'NNP']
# ['SCOTUS', 'VBZ']
# ['#texas', 'JJ']
# ['Adding', 'VBG']
# ['progress', 'NN']
# ['allowing', 'VBG']
# ['clinics', 'NNS']
# ['United', 'NNP']
# ['States', 'NNPS']
# ['#wholelife', 'JJ']
# ['back', 'JJ']
# ['alleys', 'NNS']
# ['profit', 'NN']
# ['center', 'NN']
# ['conditioning', 'NN']
# ['spirits', 'NNS']
# ['BLOODLINE', 'NNP']
# ['YOUR', 'JJ']
# ['Bloodline', 'NN']
# ['NEVER', 'NNP']
# ['REINCARNATE', 'NNP']
# ['AGAIN', 'NNP']
# ['landed', 'VBN']
# ['#Texas', 'NNP']
# ['#clinics', 'NNS']
# ['#issues', 'NNS']
# ['Progress', 'NNP']
# ['#AfricanAmericans', 'NNPS']
# ['#Women', 'NNP']
# ['waiting', 'NN']
# ['Happy', 'NNP']
# ['blocked', 'VBD']
# ['closing', 'VBG']
# ['TX', 'NNP']
# ['appeal', 'NN']
# ['heard', 'VBN']
# ['#safelegalrare', 'JJ']
# ['#thinkprogress', 'NN']
# ['@Chris_1791', 'NNP']
# ['@Doodisgirl', 'NNP']
# ['thought', 'VBD']
# ['tissue', 'NN']
# ['Sweat', 'NNP']
# ['cut', 'VBN']
# ['extreme', 'JJ']
# ['deadbeat', 'JJ']
# ['#scotusabortion', 'JJ']
# ['shut', 'VBN']
# ['@jacelarson', 'NN']
# ["He's", 'NNS']
# ['concerned', 'VBN']
# ['Stay', 'NNP']
# ['outta', 'NN']
# ['Mr', 'NNP']
# ['Patrick', 'NNP']
# ['poor', 'JJ']
# ['justices', 'NNS']
# ['@Clifford1462', 'NN']
# ['reduces', 'VBZ']
# ['honoring', 'VBG']
# ['#SameSexMarriage', 'JJ']
# ['#180themovie', 'JJ']
# ['#AudacityMovie', 'NNP']
# ['Roberts', 'NNP']
# ['Scalia', 'NNP']
# ['Alito', 'NNP']
# ['Thomas', 'NNP']
# ['R-SCAT', 'NNP']
# ['Protesters', 'NNPS']
# ["wd'rather", 'NN']
# ['spray', 'NN']
# ['paint', 'VBP']
# ['#Confederate', 'JJ']
# ['symbols', 'NNS']
# ['concern', 'NN']
# ['Lost', 'VBD']
# ['Coming', 'VBG']
# ['female', 'NN']
# ['@StAlbertCIVC', 'NNP']
# ['policy', 'NN']
# ['info', 'NN']
# ['presented', 'VBN']
# ['whole', 'NN']
# ['listed', 'VBN']
# ['Partner', 'NNP']
# ['@SenatorLankford', 'NNP']
# ['awful', 'JJ']
# ['represent', 'VB']
# ['#prolove', 'JJ']
# ['#proeducation', 'NN']
# ['#prohealthcare', 'NN']
# ['Mass', 'NNP']
# ['State', 'NNP']
# ['House', 'NNP']
# ['tomorrow', 'NN']
# ["Parenthood's", 'NNP']
# ['Sexual', 'NNP']
# ['Lobby', 'NNP']
# ['#ReproductiveJustice', 'NNP']
# ['#Feminism', 'NNP']
# ['HEAVEN', 'NNP']
# ['#ProMarriage', 'NNP']
# ['#ProFaith', 'NNP']
# ['#EternalLifeMatters', 'VBZ']
# ['answerable', 'JJ']
# ['Basil', 'NNP']
# ['self-defense', 'JJ']
# ['shooting', 'VBG']
# ['rapist', 'NN']
# ['Kittington', 'NNP']
# ['#TCOT', 'NNP']
# ['Americans', 'NNPS']
# ['Cutting', 'VBG']
# ['Title', 'NNP']
# ['X', 'NNP']
# ['#ProtectPrevention', 'NNP']
# ['#savetitleX', 'NNP']
# ['#DonRients', 'NNS']
# ['died', 'VBD']
# ['daily', 'JJ']
# ['@MarthaPlimpton', 'NNP']
# ['Twitter', 'NNP']
# ['wing', 'NN']
# ['troll', 'NN']
# ['sends', 'VBZ']
# ['#ReproRights', 'NNP']
# ['ALSO', 'NNP']
# ['fuck', 'NN']
# ['gives', 'VBZ']
# ['@OnlineForLife', 'NNP']
# ['communicate', 'VB']
# ['@__HisKindaCrazy', 'NNP']
# ['@_QueenTacoBell', 'NNP']
# ['judge', 'VB']
# ['successful', 'JJ']
# ['#Choice', 'NNP']
# ['@Anti_Fox_News', 'NNP']
# ['@MannyMooncup', 'NNP']
# ['@MattSears4', 'NNP']
# ['@FactsVsOpinion', 'NNP']
# ['Hypocrisy', 'NNP']
# ['#QuitKillingGirls', 'NNP']
# ['Kenya', 'NNP']
# ['demand', 'NN']
# ['#FIDA', 'NNP']
# ['American', 'JJ']
# ['Texan', 'NN']
# ['@FoxNews', 'NNP']
# ['prolifers', 'NNS']
# ['Describe', 'VB']
# ['caused', 'VBN']
# ['repression', 'NN']
# ['racism', 'NN']
# ['group', 'NN']
# ['#DredScott', 'NNP']
# ['#Marriage', 'NNP']
# ['Sweden', 'NNP']
# ['@LETAccess', 'JJ']
# ['#womangolf', 'JJ']
# ['#letsgooo', 'NN']
# ['tis', 'NNS']
# ['beings', 'NNS']
# ['harvest', 'NN']
# ['transplant', 'VB']
# ['organs', 'NNS']
# ['Breda', 'NNP']
# ["O'Brien", 'NNP']
# ['strikes', 'VBZ']
# ['allow', 'VB']
# ['@Paul71', 'NNP']
# ["Who's", 'NNP']
# ['yer', 'NN']
# ['bullying', 'VBG']
# ['Fine', 'NNP']
# ['Gael', 'NNP']
# ['members', 'NNS']
# ['@sassy_gramma', 'NN']
# ['point', 'NN']
# ['unplanned', 'JJ']
# ['spouses', 'NNS']
# ['#Life', 'NNP']
# ['#USA', 'NNP']
# ['rid', 'VBN']
# ['pretends', 'VBZ']
# ['existed', 'VBD']
# ['#ParentTrapPlot', 'NNP']
# ['@wendydavis', 'NNS']
# ['Pray', 'NNP']
# ['dangerous', 'JJ']
# ['facilities', 'NNS']
# ['remain', 'VBP']
# ['unchecked', 'JJ']
# ['#facepalm', 'VB']
# ['prevent', 'VB']
# ['#feminists', 'NNS']
# ['#feminazi', 'NNS']
# ['arguments', 'NNS']
# ['ban', 'VB']
# ['painful', 'JJ']
# ['late-term', 'JJ']
# ['accountable', 'JJ']
# ['#bluemoon', 'NN']
# ['thrilled', 'VBN']
# ['announce', 'VB']
# ['opening', 'VBG']
# ['satellite', 'NN']
# ['office', 'NN']
# ['street', 'NN']
# ['#ASU', 'NNP']
# ['Fed', 'NNP']
# ['til', 'JJ']
# ['sec', 'NN']
# ['address', 'VB']
# ['root', 'NN']
# ['Way', 'NNP']
# ['Mozambique', 'NNP']
# ['recognizing', 'VBG']
# ['NOT', 'NN']
# ['mass', 'NN']
# ['help', 'NN']
# ['options', 'NNS']
# ['Very', 'NNP']
# ['providing', 'VBG']
# ['@NARALVirginia', 'NNP']
# ['TRAP', 'NNP']
# ['regulations', 'NNS']
# ['#scraptrap', 'NN']
# ['crudest', 'JJS']
# ['form', 'NN']
# ['#Conservative', 'JJ']
# ['#feminist', 'JJ']
# ['deal', 'NN']
# ['ways', 'NNS']
# ['@helenantanova', 'NNP']
# ['Turning', 'VBG']
# ['racial', 'JJ']
# ['kek', 'JJ']
# ['@StevenErtelt', 'NNP']
# ['@GM_GXPfan', 'NNP']
# ['young', 'JJ']
# ['regrets', 'VBZ']
# ['@KarrattiPaul', 'NNP']
# ['@chooseliferacer', 'NN']
# ["gov't", 'VB']
# ['largest', 'JJS']
# ['corporation', 'NN']
# ['Defund', 'NNP']
# ['fuNk', 'NN']
# ['Chris', 'NNP']
# ['Christy', 'NNP']
# ['Republican', 'NNP']
# ['hes', 'VBZ']
# ['RINO', 'NNP']
# ['#1A', 'NNP']
# ['#NRA', 'NNP']
# ['#COS', 'NNP']
# ['#TGDN', 'NNP']
# ['political', 'JJ']
# ['HHS', 'NNP']
# ['contraceptive', 'JJ']
# ['mandate', 'NN']
# ['challenged', 'VBN']
# ['#SCOUTS', 'NNP']
# ['lost', 'VBN']
# ['#contraception', 'NN']
# ['Starbucks', 'JJ']
# ['majority', 'NN']
# ['substitute', 'NN']
# ['capital', 'NN']
# ['settled', 'VBN']
# ['[', 'JJ']
# [']', 'NN']
# ['follows', 'VBZ']
# ['means', 'NN']
# ['Put', 'VBN']
# ['Est', 'NNP']
# ['rape-caused', 'JJ']
# ['less', 'JJR']
# ['est', 'JJS']
# ['#StrawMan', 'NNP']
# ['#WarOnWomen', 'NNP']
# ['@saintjohnfargo', 'NN']
# ['@chrisgeidner', 'NN']
# ['@tweetbrk', 'NN']
# ['Ginsburg', 'NNP']
# ['calls', 'VBZ']
# ['@DarkTechMonitor', 'NNP']
# ['@Colonel_Ted', 'NNP']
# ['preventing', 'VBG']
# ['terminating', 'VBG']
# ['@UberFacts', 'NNS']
# ['utilized', 'VBN']
# ['wonderful', 'JJ']
# ['#proChoice', 'NN']
# ['percent', 'NN']
# ['antiabortion', 'JJ']
# ['protestors', 'NNS']
# ['Calmer', 'JJR']
# ['buying', 'VBG']
# ['bi', 'NN']
# ['colour', 'JJ']
# ['yarn', 'NN']
# ['Haberdashery', 'NN']
# ['Mary', 'NNP']
# ['persecuted', 'VBN']
# ['#HolyLove', 'NNP']
# ['#UnitedHearts', 'NNPS']
# ['#MaranathaSnS', 'NNP']
# ['#profamily', 'JJ']
# ['#1m1w', 'NN']
# ['doubt', 'VBP']
# ['clothed', 'VBN']
# ['occurred', 'VBD']
# ["#Mozambique's", 'NNP']
# ['penal', 'JJ']
# ['code', 'NN']
# ['effect', 'NN']
# ['containing', 'VBG']
# ['several', 'JJ']
# ['significant', 'JJ']
# ['elements', 'NNS']
# ['#decriminalisation', 'NN']
# ['Rock', 'NNP']
# ['begin', 'VBP']
# ['prayer', 'NN']
# ['Ephraem', 'NNP']
# ['Syrian', 'JJ']
# ['Abortionists', 'NNS']
# ['refused', 'VBD']
# ['common-sense', 'JJ']
# ['standards', 'NNS']
# ['#NARAL', 'NNP']
# ['sinister', 'JJ']
# ['NAZI-esque', 'JJ']
# ['folks', 'NNS']
# ['#qanda', 'JJ']
# ['Suffer', 'NNP']
# ['Mk', 'NNP']
# ['coffee', 'NN']
# ['nose', 'NN']
# ['windpipe', 'NN']
# ['#thoughtiwasgonnadie', 'NN']
# ['@ToddPuckett1', 'NNP']
# ['discussed', 'VBD']
# ['Business', 'NNP']
# ['calculates', 'VBZ']
# ['risk', 'NN']
# ['factors', 'NNS']
# ['Drew', 'NNP']
# ['attacking', 'VBG']
# ['#SpaceX', 'NN']
# ['inferring', 'VBG']
# ['invoked', 'VBD']
# ["mother's", 'JJ']
# ['churches', 'NNS']
# ['#WhoIsBurningBlackChurches', 'NNP']
# ['Ohio', 'NNP']
# ['restrictive', 'JJ']
# ['#TRAPlaws', 'NNP']
# ['BABIES', 'NNP']
# ['Urgent', 'NNP']
# ['Detroit', 'NNP']
# ['MI', 'NNP']
# ['San', 'NNP']
# ['Diego', 'NNP']
# ['CA', 'NNP']
# ['Antonio', 'NNP']
# ['#Florida', 'NNP']
# ['AttorneyGeneralBondi', 'NNP']
# ['files', 'VBZ']
# ['grants', 'NNS']
# ['ACLU', 'NNP']
# ['request', 'NN']
# ['halt', 'VB']
# ['requiring', 'VBG']
# ['hr', 'NN']
# ['wait', 'NN']
# ['stem', 'NN']
# ['smashing', 'NN']
# ['Bernie', 'NNP']
# ['Sanders', 'NNP']
# ["won't", 'JJ']
# ['share', 'NN']
# ['puzzled', 'VBN']
# ['@HomunculusLoikm', 'NNP']
# ['@SawyerAndrew', 'NNP']
# ['@BryanBroome1', 'NNP']
# ['enjoy', 'VBP']
# ['experience', 'NN']
# ['analogy', 'NN']
# ['current', 'JJ']
# ['frame', 'NN']
# ['@MI_IMMACULATA', 'NNP']
# ['@GLORYtoGOD_143', 'NNP']
# ['@BenignoVito', 'NNP']
# ['#PrayTheRosary', 'NNP']
# ['#PrayforthePersecutedChurch', 'NNP']
# ['belongs', 'VBZ']
# ['belong', 'VBP']
# ['embryo', 'NN']
# ["person's", 'NNS']
# ['cease', 'VBP']
# ['nuts', 'NNS']
# ['#Onepercent', 'NN']
# ['fate', 'NN']
# ['#obamacare', 'JJ']
# ['@LisetteHasHope', 'NNP']
# ['@theRallyforLife', 'NN']
# ['Counting', 'VBG']
# ['recieve', 'VB']
# ['treatment', 'NN']
# ['#PeoplesDebate', 'NNP']
# ['Juvenile', 'NNP']
# ['hysterics', 'NNS']
# ['dying', 'VBG']
# ['neglect', 'NN']
# ['#VinB', 'NNP']
# ['#PeoplesDebate', 'NN']
# ['+', 'NNS']
# ['#loneparents', 'NNS']
# ['allowance', 'NN']
# ['@toby_dorena', 'NN']
# ['chose', 'VBD']
# ['irrelevant', 'JJ']
# ['gray', 'JJ']
# ['area', 'NN']
# ['discuss', 'VB']
# ['#legal', 'JJ']
# ['#ethical', 'JJ']
# ['#dilemmas', 'NNS']
# ['#doctors', 'NNS']
# ['#patients', 'NNS']
# ['face', 'VBP']
# ['regarding', 'VBG']
# ['bornKills', 'NNS']
# ['@mrgeology', 'NN']
# ['#Downfall', 'NNP']
# ['@Canuckle_head', 'NNP']
# ['@Atheist_Roo', 'NNP']
# ['@atxbantamathy', 'JJ']
# ['gags', 'NNS']
# ['Dat', 'NNP']
# ['face', 'NN']
# ['@notmuchelse', 'NN']
# ['KILLS', 'NNP']
# ['turn', 'VB']
# ['deadly', 'JJ']
# ['warning', 'NN']
# ['force', 'NN']
# ['#Love', 'NNP']
# ['delight', 'VB']
# ['#evil', 'NN']
# ['#rejoices', 'NNS']
# ['#truth', 'JJ']
# ['Cor', 'NNP']
# ['#Loving', 'NN']
# ['requires', 'VBZ']
# ['#ProtestChildKilling', 'NNP']
# ['vaginas', 'NNS']
# ['legitimize', 'VB']
# ['bedrooms', 'NNS']
# ['Curious', 'JJ']
# ['Charged', 'VBN']
# ['Manslaughter', 'NNP']
# ['@ghhshirley', 'JJ']
# ['Workers', 'NNPS']
# ['Charged', 'NNP']
# ['@WordfactoryQ', 'NNP']
# ['@LeahNTorres', 'NNP']
# ['@NARAL', 'NNP']
# ['@TIME', 'NNP']
# ['guilt-trip', 'JJ']
# ['agonist', 'NN']
# ['vasectomy', 'JJ']
# ['bring', 'VBP']
# ['offended', 'VBN']
# ['eagles', 'NNS']
# ['idk', 'NN']
# ["you've", 'NN']
# ['#AbortionOnDemand', 'NNP']
# ['#MenstruationMatters', 'VBZ']
# ['preference', 'NN']
# ['dare', 'VBP']
# ['dismembering', 'VBG']
# ['#liberalism', 'NN']
# ['seals', 'NNS']
# ['legacy', 'NN']
# ['doz', 'NN']
# ['wins', 'NNS']
# ['Repeal', 'NN']
# ['#Gun', 'NNP']
# ['Ban', 'NNP']
# ['Access', 'NNP']
# ['#TotalLosers', 'NNP']
# ['#NoIdeas', 'NNP']
# {'consider': ['VB'], '#WAAR': ['NNP'], 'proof': ['NN'], 'strikes': ['VBZ'], 'Obamcare': ['NNP'], '@bindelj': ['VBN'], '#UniteBlue': ['NNP'], 'dismember': ['VB'], 'cunt': ['NN'], '@AmnestyOnline': ['NNP'], 'tell': ['VB', 'VBP'], '#prowomen': ['NNS'], 'stop': ['VB', 'NN'], '#Onepercent': ['NN'], 'choice': ['NN'], 'uterus': ['NN'], 'premeditated': ['VBD'], 'i': ['NNS', 'NNP'], 'goes': ['VBZ'], 'sinners': ['NNS'], '#dismembering': ['VBG'], '#liberalism': ['NN'], 'chase': ['VB'], '#thebriefcase': ['NN'], '@CoraSherlock': ['NNP'], '#thoughtiwasgonnadie': ['NN'], 'putting': ['VBG'], 'supported': ['VBD'], 'trying': ['VBG'], 'deciding': ['VBG'], 'Captors': ['NNPS'], 'posting': ['VBG'], '@GM_GXPfan': ['NNP'], 'abolish': ['VB'], 'ts': ['NNS'], '@GlennBeck': ['NNP'], 'fetuses': ['NNS'], '#TaxpayerPride': ['NNP'], 'includes': ['VBZ'], 'harassing': ['VBG'], 'gays': ['NNS'], 'codes': ['NNS'], '#MyuranSukumaran': ['NNP'], 'homes': ['NNS'], 'ONLY': ['NNP'], 'PRODUCE': ['NNP'], 'opportunity': ['NN'], 'kids': ['NNS'], '@LifeNewsHQ': ['NNP'], 'hat': ['NN'], 'bless': ['VB'], 'slaying': ['NN'], 'resolve': ['VB'], 'Gael': ['NNP'], 'stick': ['VB'], '@POTUS': ['NNP'], 'mbuli': ['NNS'], '@reggielittlejhn': ['VB'], '#save': ['VB'], 'Government': ['NNP'], "That's": ['NNP'], 'Kudos': ['NNP'], 'doctors': ['NNS'], 'months': ['NNS'], '#SoProLife': ['NNP'], 'Follow': ['VB'], 'Judiciary': ['NNP'], 'week': ['NN'], 'evolution': ['NN'], 'champion': ['NN'], 'bill': ['NN'], 'commentary': ['NN'], '#Racism': ['NNP'], '@Atheist_Roo': ['NNP'], 'helped': ['VBD'], '#NoToDeathPenalty': ['NNP'], 'were': ['VBD'], 'shd': ['VBD'], 'brings': ['VBZ'], '@hoursofChaos': ['VBZ'], 'im': ['NN'], "you've": ['NN'], '#Losers': ['NNPS'], '#Baltimore': ['NNP'], '#AudacityMovie': ['NNP'], 'missing': ['VBG'], 'Findin': ['NNP'], 'MLK': ['NNP'], '@NORTHANNE': ['NNP'], 'REINCARNATE': ['NNP'], 'speaking': ['VBG'], 'Please': ['VB'], 'Disguise': ['NNP'], 'guarantee': ['VBP'], 'Bl': ['NNP'], 'legs': ['NNS'], 'gets': ['VBZ'], 'pops': ['VBZ'], 'leading': ['VBG'], '#LetthemLive': ['NNP'], 'protection': ['NN'], '@SayNoToSuicide4': ['NNP'], '#Secularism': ['NNP'], 'dancing': ['VBG'], 'poll': ['NN'], 'fed': ['NN'], '#smartlady': ['NN'], 'mint': ['NN'], 'govt': ['NN'], 'occurred': ['VBD'], 'Spotlight': ['NNP'], 'isright': ['NN'], 'wait': ['NN'], 'got': ['VBD'], "Who's": ['NNP'], 'Makes': ['VBZ'], '#Baby': ['NNP'], '@Docjp': ['NNP'], 'Mary': ['NNP'], '@sinnfeinireland': ['NN'], 'murders': ['NNS'], 'straw': ['NN'], '#deathpenalty': ['NN'], '@Canuckle_head': ['NNP'], 'demand': ['NN'], 'ruled': ['VBD'], '#Psalm106': ['NNP'], "women's": ['NNS'], 'spray': ['NN'], 'MATTER': ['NNP'], 'penalty': ['NN'], '@UCBerkeley': ['NNP'], 'discover': ['VBP'], '#baby': ['NN'], 'anti-choicers': ['NNS'], '#LifeisaGift': ['NNP'], 'JPII': ['NNP'], 'Farrah': ['NNP'], '#help': ['NN'], 'Four': ['NNP'], 'biases': ['NNS'], 'saying': ['VBG'], 'Consenting': ['VBG'], '#wrp': ['NN'], 'States': ['NNPS'], 'clinics': ['NNS'], 'image': ['NN'], 'Antonio': ['NNP'], 'whole': ['NN'], 'stoping': ['VBG'], 'bitch': ['NN'], '#coffee': ['NN'], "They'd": ['NNP'], 'Hitler': ['NNP'], 'bit': ['NN'], '@dave_gosh': ['NN'], 'debate': ['NN'], '#clinics': ['NNS'], 'movement': ['NN'], 'anyone': ['NN'], 'has': ['VBZ'], 'boys': ['NNS'], 'Brownback': ['NNP'], 'Legislative': ['NNP'], 'Stevens': ['NNP'], 'right': ['NN'], 'calling': ['VBG'], 'Very': ['NNP'], 'House': ['NNP'], 'daughter': ['NN'], '#peipoli': ['NNS', 'NNP'], 'predicted': ['VBD'], 'dignity': ['NN'], 'airtight': ['NN'], 'ability': ['NN'], 'Alaska': ['NNP'], 'sigh': ['NN'], 'means': ['VBZ', 'NNS', 'NN'], '@DRUDGE_REPORT': ['NNP'], 'hospitals': ['NNS'], 'treated': ['VBN'], 'add': ['VB'], '@kilcurry': ['VB'], 'Dehumanizing': ['NNP'], 'ban': ['VB'], '@Pontifex': ['NNP'], '@GolfProYYC': ['NNP'], 'definitions': ['NNS'], 'ending': ['VBG'], '#JulieBorowski': ['NNP'], 'join': ['VB'], 'VAN': ['NN'], '@hillaryclinton': ['NN'], '#shahs': ['NNS'], 'America': ['NNP'], 'dies': ['VBZ'], '@politicspizza': ['NN'], '@TODA ...
# list-Train-Atheism.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-8005369b7c0c> in <module>()
#      16     with open(folder+file,"rt") as file_obj:
#      17         reader = csv.reader(file_obj,skipinitialspace=True,delimiter="\t")
# ---> 18         for row in reader:
#      19             print (row)
#      20             if LineCount>11:
#
# C:\Users\sriram\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 1149: character maps to <undefined>

# %%
##Arguing lexicon
#Creating for total dictionary for Macros
import json
from os import listdir
from os.path import isfile, join
from pprint import pprint
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\arglex_Somasundaran07\\Macros\\"
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]
#macros=[]
#for file in onlyfiles:
with open(folder+"TotalMacro.json") as data_file:    
    macro=json.load(data_file)

# %%
macro
# Out:
# {'@ABLE': ['able', 'unable'],
#  '@AINT': ['ain"t'],
#  '@BE': ['be', 'is', 'am', 'are', 'were', 'was', 'been', 'being'],
#  '@BECL': ['he"s',
#   'I"m',
#   'it"s',
#   'she"s',
#   'they"re',
#   'we"re',
#   'you"re',
#   ' that"s'],
#  '@BENEG': ['aren"t',
#   'isn"t',
#   'wasn"t',
#   'weren"t',
#   ' am not',
#   ' is not',
#   ' are not',
#   ' was not',
#   ' were not'],
#  '@CAN': ['can', 'could'],
#  '@CANHAVE': ['can have', ' could have', ' could"ve'],
#  '@CANNEG': ['cannot', 'can"t', 'couldn"t', ' could not'],
#  '@DARE': ['dare'],
#  '@DARENEG': ['daren"t', ' dare not'],
#  '@DO': ['do', ' does'],
#  '@DONEG': ['doesn"t', 'don"t'],
#  '@DYS': ['uh', 'um', 'mm-hmm', 'uh-huh', 'huh'],
#  '@EMO1N': ['like', 'adoration', 'want', 'preference', 'love', 'enjoyment'],
#  '@EMO1V': ['like', 'adore', 'want', 'prefer', 'love', 'enjoy'],
#  '@EMO2N': ['hate', 'dislike', 'dispreference'],
#  '@EMO2V': ['hate', 'dislike', 'disprefer'],
#  '@GONNA': ['am going to',
#   ' are going to',
#   ' is going to',
#   ' am gonna',
#   ' are gonna',
#   ' is gonna'],
#  '@GONNACL': ['i"m going to',
#   ' they"re going to',
#   ' she"s going to',
#   ' it"s going to',
#   ' we"re going to',
#   ' i"m gonna',
#   ' you"re gonna',
#   ' i"m gonna',
#   ' you"re gonna',
#   ' he"s gonna',
#   ' she"s gonna',
#   ' it"s gonna',
#   ' we"re gonna',
#   ' they"re gonna',
#   ' that"s gonna'],
#  '@GONNANEG': ['am not going to',
#   ' are not going to',
#   ' is not going to',
#   ' am not gonna',
#   ' are not gonna',
#   ' is not gonna',
#   ' ain"t gonna',
#   ' isn"t gonna',
#   ' aren"t gonna'],
#  '@GONNANEGCL': ['i"m not going to',
#   ' they"re not going to',
#   ' she"s not going to',
#   ' it"s not going to',
#   ' we"re not going to',
#   ' i"m not gonna',
#   ' you"re not gonna',
#   ' he"s not gonna',
#   ' she"s not gonna',
#   ' it"s not gonna',
#   ' we"re not gonna',
#   ' they"re not gonna',
#   ' that"s not gonna'],
#  '@HAVE': ['have', 'has', 'had', 'having'],
#  '@HAVECL': ['i"ve',
#   ' you"ve',
#   ' she"s',
#   ' he"s',
#   ' we"ve',
#   ' they"ve',
#   ' it"s',
#   ' that"s',
#   ' this"s'],
#  '@HAVEGOTTA': ['has got to',
#   ' has gotta',
#   ' have got to',
#   ' have gotta',
#   ' gotta'],
#  '@HAVEGOTTACL': ['it"s gotta',
#   ' it"s got to',
#   ' he"s got to',
#   ' he"s gotta',
#   ' she"s got to',
#   ' she"s gotta',
#   ' i"ve gotta',
#   ' i"ve got to',
#   ' we"ve gotta',
#   ' we"ve got to',
#   ' they"ve got to',
#   ' they"ve gotta',
#   ' you"ve got to',
#   ' you"ve gotta',
#   ' that"s got to',
#   ' that"s gotta',
#   ' this"s gotta',
#   ' this"s got to'],
#  '@HAVEGOTTANEG': ['hasn"t got to',
#   ' hasn"t gotta',
#   ' haven"t got to',
#   ' haven"t gotta',
#   ' ain"t gotta',
#   ' ain"t got to'],
#  '@HAVENEG': ['haven"t',
#   'hasn"t',
#   'hadn"t',
#   ' had not',
#   ' has not',
#   ' have not'],
#  '@HE': ['he', 'he"s', 'he"ll', 'he"d,him'],
#  '@I': ['i', 'i"m', 'i"ve', 'i"ll', 'i"d', 'me'],
#  '@INTENSADJ1': ['absolute',
#   'extreme',
#   'incredible',
#   'perfect',
#   'phenomenal',
#   'spectacular',
#   'huge',
#   'major',
#   'tremendous',
#   'complete',
#   'considerable',
#   'real',
#   'terrible',
#   'total',
#   'unbelievable',
#   'utter',
#   'great',
#   'resounding'],
#  '@INTENSADV1': ['absolutely',
#   'absurdly',
#   'resoundingly',
#   'amazingly',
#   'awfully',
#   'extremely',
#   'completely',
#   'highly',
#   'incredibly',
#   'perfectly',
#   'quite',
#   'really',
#   'strikingly',
#   'surprisingly',
#   'terribly',
#   'totally',
#   'unbelievably',
#   'hugely',
#   'unnaturally',
#   'unusually',
#   'utterly',
#   'very',
#   'tremendously',
#   'spectacularly'],
#  '@MAY': ['may', 'might'],
#  '@MAYHAVE': ['may have', ' might have', ' might"ve', ' may"ve'],
#  '@MAYNEG': ['may not', 'might not', 'mightn"t', ' mayn"t'],
#  '@MAYNEGHAVE': ['may not have',
#   ' might not have',
#   ' mightn"t have',
#   ' mayn"t have'],
#  '@MODAL': ['might',
#   'may',
#   'could',
#   'can',
#   'should',
#   'shall',
#   'will',
#   'would'],
#  '@MUST': ['must'],
#  '@MUSTHAVE': ['must have', ' must"ve'],
#  '@MUSTNEG': ['mustn"t'],
#  '@MUSTNEGHAVE': ['must not have', ' mustn"t have', ' mustn"t "ve'],
#  '@NEED': ['need'],
#  '@NEEDHAVE': ['need"ve', ' need have'],
#  '@NEEDHAVENEG': ['needn"t have', ' needn"t"ve', ' need not have'],
#  '@NEEDNEG': ['needn"t'],
#  '@OUGHT': ['ought to', ' oughta'],
#  '@OUGHTHAVE': ['ought to have', ' oughta have'],
#  '@OUGHTNEG': ['oughtn"t to'],
#  '@PRONSUBJ': ['i', 'you', 'he', 'she', 'it', 'we', 'they'],
#  '@SHALL': ['shall', 'should', ' shalt'],
#  '@SHALLHAVE': ['shall have', ' should have'],
#  '@SHALLNEG': ['shan"t', ' shouldn"t', ' shall not', ' should not'],
#  '@SHALLNEGHAVE': ['shall not have', ' should not have', ' shouldn"t have'],
#  '@SHE': ['she', 'she"s', 'she"ll', 'she"d,her'],
#  '@THEY': ['they', 'they"re', 'they"ll', 'they"d', 'they"ve,them'],
#  '@USEDTO': ['used to'],
#  '@WE': ['we', 'we"re', 'we"ll', 'we"d', 'we"ve,us'],
#  '@WILL': ['will', ' would'],
#  '@WILLCL': ['i"ll', ' you"ll', ' she"ll', ' he"ll', 'that"ll', ' this"ll'],
#  '@WILLNEG': ['wouldn"t', 'won"t', ' will not', ' would not'],
#  '@WOULDCL': ['you"d',
#   'he"d',
#   'I"d',
#   'it"d',
#   'she"d',
#   'they"d',
#   'we"d',
#   ' that"d',
#   ' this"d'],
#  '@YOU': ['you', 'you"re', 'you"ve', 'you"ll', 'you"d']}

# %%
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\arglex_Somasundaran07\\"
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]
FeautureRegexList=[]
import re
for file in onlyfiles:
    LineCount=0
    inp=open(folder+file)
    regexList=[]
    for line in inp:
        if LineCount>0:
            line=line.replace("\n","")
            #print (re.sub(r"\\\\", r"\\",line))
            regexList.append(re.sub(r"\\\\", r"",line))
        LineCount+=1
    inp.close()
    #break
    FeautureRegexList.append(regexList)

# %%
x=FeautureRegexList[7][4]
p=re.compile(x,re.IGNORECASE)
print (p)
#m=re.match(FeautureRegexList[7][4],"it's pretty evident that")
#print (m)
#if m:
#   print (True)
if p.match("it's pretty evident that"):
    print (True)
# Out:
# re.compile("(it is|it\\'s) ((really|pretty) )?(obvious|evident|clear) (that)?", re.IGNORECASE)
# True

# %%
#replacemacro=[5,7,11,12,14]
replacemacro=[]
for i in range(len(FeautureRegexList)):
    replaceList=FeautureRegexList[i]
    temp=[]
    for regx in replaceList:
        lenCheck=0
        print (regx)
        atCheck=re.findall("\(@[A-Z,0-9]* ?\)",regx)
        regxMacros=[i.replace("(","").replace(")","") for i in atCheck]
        if len(atCheck)>0:
            lenCheck=1
        else:
            lenCheck=0
        newRegx=regx
        for mac in regxMacros:
            replaceString=" |".join(macro[mac.replace(" ","")])
            mac="("+mac+")"
            newRegx=newRegx.replace(mac,"("+replaceString+ " )")
        if lenCheck==1:
            temp.append(newRegx.replace(") ",")").replace("\"","\'"))
        else:
            temp.append(regx)
    replacemacro.append(temp)
# Out:
# (our|my) (opinion|understanding) (is|was) that
# it (is|was) (our|my) (opinion|understanding) (that)?
# in (our|my) opinion
# (our|my) take on
# it (seems|seemed) to (us|me) (that)?
# it (seems|seemed) (that)?
# it would seem to (us|me)?
# it would appear to (us|me)?
# it appears to (us|me)?
# (the|my|our) ([\w]+[ ])?point is (that)?
# (the|my|our) ([\w]+[ \,]*){1,2} point is (that)?
# it (looks|looked) to (us|me) (as if|like)
# it (looks|looked) (as if|like|that way)
# (we|i) (have|get|got) the impression (that)?
# (our|my) impression (was|is) (that)?
# in (our|my) book
# to (our|my) mind
# to (our|my) way of thinking
# as far as (I am|I was|we are|we were) concerned
# if you ask (me|us)
# (our|my) feeling (is|was|would be)
# from where (I\'m|I am) (standing|sitting)
# (we|I) (don\'t)? think (that)?
# all (we\'re|I\'m) saying is
# what (I\'m|we\'re) saying is
# (we\'re|I\'m) (not)? saying that
# what (we\'re|i\'m) trying to say is
# what (we|i) mean is (that)?
# according to
# so
# therefore
# because
# hence
# as a result
# consequently
# if (we|you) want to ([\w]+[ \,]+){1,7}(we|you) (need to|must|have to)
# (we|you) ([\w ,]+) (must|have to|need to) ([\w]+[ \,]+){1,7}if  (you|we) want to
# it would be ([\w]+[ \,]+){0,2}nice if
# wouldn\'t it be ([\w]+[ \,]+){0,2}nice if
# if ([\w]+[ \,]+){3,8} that would be ([\w]+[ \,]+){0,2}nice
# (cannot|will not|won\'t|can\'t) ([\w]+[ \,]+){1,7}(if|unless)
# (if|unless) ([\w]+[ \,]+){3,10}(cannot|will not|won\'t|can\'t)
# (need|needs|must|has to|have to) ([\w]+[ \,]+){3,10}(in order )to
# (in order )?to ([\w]+[ \,]+){3,10}(need|needs|must|has to|have to)
# as long as (we|you) ([\w]+[ \,]+){3,10}(will|can|able|should|[a-zA-Z]+\'ll)
# ([a-zA-Z]\'ll|will|can|able|should) ([\w]+[ \,]+){3,10}as long as (we|you)
# (you|he|we) better ([\w]+[ \,]+){3,10}or
# otherwise
# really
# actually
# as opposed to
# instead of
# rather than
# there (are|is) ([\w]+[ \,]*){1,4} and (then )?there (are|is)
# (is|that\'s|it\'s) a whole nother issue
# (is|are|that\'s|it\'s) (very|quite|completely|totally )?different
# whole new ballgame
# (is|that\'s|it\'s) a (separate|different) (issue|question)
# (@BE) (@INTENSADV1)?easy
# (@BE) a (@INTENSADJ1)?breeze
# (@BE) a (@INTENSADJ1)?walk in the park
# (@BE) a (@INTENSADJ1)?piece of cake
# (@BE) a (@INTENSADJ1)?snap
# (@BE) a (@INTENSADJ1)?cinch
# (@BE) (@INTENSADJ1)?child's play
# (@BE) (@INTENSADV1)?difficult
# (@BE) a (@INTENSADJ1)?pain
# (@BE) a (@INTENSADJ1)?pain in the (butt|neck|ass)
# (@BE) a (@INTENSADJ1)?(bitch|bastard) to
# (@BE) no picnic
# (@BE) (@INTENSADV1)?tricky
# (@BE) (@INTENSADV1)?arduous
# (@BE) a (@INTENSADJ1)?challenge
# (@BE) (@INTENSADV1)?challenging
# (@HAVE) a (@INTENSADV1)?(hard|difficult) time
# (i am|i\'m) not (sure|convinced)
# i (don\'t|can\'t|do not|cannot) see how
# it (is not|isn\'t) (clear|evident|obvious) (that)?
# it\'s not (clear|evident|obvious) (that)?
# (we|i) doubt (that)?
# (we|i) (am|are) doubtful
# (we\'re|i\'m) doubtful
# clearly
# obviously
# patently
# when you (really )?think about it
# (it is|it\'s) ((really|pretty) )?(obvious|evident|clear) (that)?
# definitely
# i have to say
# i\'ve got to say
# i\'ve gotta say
# i should say
# surely
# for sure
# (@BE) ((sure)|(certain)|(confident)) (that)?
# of course
# no doubt about it
# doubtless
# without a doubt
# I have no doubt (that)?
# I bet (that)?
# (@BE) bound to
# no two ways about it
# there ((is)|(are)) no two ways about it
# there\'s no two ways about it
# ((the)|(one)) ((thing)|(issue)|(question)|(problem)) (@MODAL )?(@BE) (that)?
# my feeling is (that)?
# that\'s why
# that is why
# the idea (here )?is (that)?
# ((my)|(the)) whole ((point)|(question)) is
# what you have to do is
# the reason is (that)?
# here\'s what
# here is what
# exactly
# precisely
# (@GONNA)
# (@GONNANEG)
# (@GONNANEGCL)
# (@GONNACL)
# what will happen is
# what\'ll happen is
# what\'s ((gonna)|(going to)) happen is
# what is ((gonna)|(going to)) happen is
# i want to (highlight|emphasize|underscore)
#
# (everybody|everything|anybody|anything|nobody|nothing) (else|at all)
# in the (world|universe)
# of all times
# in recent memory
# in living history
# except that
# except for
# with the exception of
# however
# nevertheless
# that said
# that having been said
# that being said
# despite
# in spite of
# even so
# at the same time
# still
# wait a minute
# hold on a second
# hold on a sec
# it\'s just that
# all well and good
# as far as it goes
# you might think (that)?
# you may think (that)?
# what i would do
# if i were you
# i would not
# i wouldn\'t
# a must
# must
# essential
# indispensable
# necessary
# (@BE) a necessity
# needed
# required
# requirement
# can\'t do without
# got to
# gotta
# had better
# hafta
# have to
# has to
# need to
# needs to
# ought to
# oughta
# should
# (@PRONSUBJ) better
# (necesssitates|necessitated|necessitating|necessitate)
# you can
# we can
# you can\'t
# you cannot
# we can\'t
# we cannot
# you could
# we could
# (@BE) able to
# there\'s no way (that|for|of|to)?
# any way (that|for|of|to)?
# no way
# important
# crucial
# key
# essential
# critical
# fundamental
# key
# major
# vital
# first and foremost
# (now )?remember (that)?
# keep in mind (that)?
# don\'t forget (that)?
# let\'s not forget
# let\'s keep in mind
# let\'s remember
# do (we|you) (actually|really|still) (need|want)
# why not
# why don\'t (we|you)
# what if
# (and )?who (wouldn\'t|doesn\'t) (@EMO1V)
# first
# secondly
# first place
# in the first place
# first of all
# (you|we|i) (don\'t )?(want|wanna)
# (you|we|i) might (not )?(want|wanna)

# %%
import csv
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\Train\\"
inputFile="Train-Hilary"
from io import StringIO
#inp=open(folder+inputFile+".csv")

with open(folder+inputFile+".csv", encoding='ISO-8859-1') as file_obj:
    reader = csv.reader(file_obj,skipinitialspace=True)
    outputFile=open(folder+"Words\\"+inputFile+".txt","wb")
    for row in reader:
        words=preprocess(row[0])
        #print(words)    
        for word in words:
            #print (str.encode(word),type(str.encode(word)))
            outputFile.write(str.encode(word+"\n"))
        outputFile.write(str.encode("\n"))
outputFile.close()

# %%
import re
from os import listdir
from os.path import isfile, join
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\\Train\\"
argFolder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Final Project\\Targets\\arglex_Somasundaran07\\"
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]
ArgFeatures=[f.replace(".tff","") for f in listdir(argFolder) if '.tff' in f]
header=",".join(ArgFeatures)
print(len(replacemacro))
for file in onlyfiles:
    LineCount=0
    rowCount=0
    out=open(folder+"ArgLex Features\\ArgFeatures-"+file,"w")
    out.write(header+"\n")
    with open(folder+file,"rt", encoding='ISO-8859-1') as file_obj:
        reader = csv.reader(file_obj,skipinitialspace=True)
        for row in reader:
            if rowCount>0:    
                tweet=row[0].replace("\n","")
                Featurevalues=[]
                for i in range(len(replacemacro)):
                    currentFeature=replacemacro[i]
                    match=0
                    for regx in currentFeature:
                        p=re.compile(regx,re.IGNORECASE)
                        if p.match(tweet) and len(regx)>1:
                            #print (regx)
                            #print (tweet)
                            match+=1
                            break
                    Featurevalues.append(match)
                out.write(",".join([str(i) for i in Featurevalues])+"\n")
            rowCount+=1
    print (file)
    out.close()
# Out:
# 17
# Train-Abortion.csv
# Train-Atheism.csv
# Train-Climate.csv
# Train-Feminism.csv
# Train-Hilary.csv
# train.csv

# %%
replacemacro[7]
# Out:
# ['clearly',
#  'obviously',
#  'patently',
#  'when you (really )?think about it',
#  "(it is|it\\'s) ((really|pretty) )?(obvious|evident|clear) (that)?",
#  'definitely',
#  'i have to say',
#  "i\\'ve got to say",
#  "i\\'ve gotta say",
#  'i should say',
#  'surely',
#  'for sure',
#  '(be |is |am |are |were |was |been |being )((sure)|(certain)|(confident))(that)?',
#  'of course',
#  'no doubt about it',
#  'doubtless',
#  'without a doubt',
#  'I have no doubt (that)?',
#  'I bet (that)?',
#  '(be |is |am |are |were |was |been |being )bound to',
#  'no two ways about it',
#  'there ((is)|(are)) no two ways about it',
#  "there\\'s no two ways about it",
#  '((the)|(one))((thing)|(issue)|(question)|(problem))(might |may |could |can |should |shall |will |would )?(be |is |am |are |were |was |been |being )(that)?',
#  'my feeling is (that)?',
#  "that\\'s why",
#  'that is why',
#  'the idea (here )?is (that)?',
#  '((my)|(the)) whole ((point)|(question)) is ',
#  'what you have to do is ',
#  'the reason is (that)?  ',
#  "here\\'s what",
#  'here is what',
#  'exactly',
#  'precisely',
#  '(am going to | are going to | is going to | am gonna | are gonna | is gonna )',
#  "(am not going to | are not going to | is not going to | am not gonna | are not gonna | is not gonna | ain't gonna | isn't gonna | aren't gonna )",
#  "(i'm not going to | they're not going to | she's not going to | it's not going to | we're not going to | i'm not gonna | you're not gonna | he's not gonna | she's not gonna | it's not gonna | we're not gonna | they're not gonna | that's not gonna )",
#  "(i'm going to | they're going to | she's going to | it's going to | we're going to | i'm gonna | you're gonna | i'm gonna | you're gonna | he's gonna | she's gonna | it's gonna | we're gonna | they're gonna | that's gonna )",
#  'what will happen is',
#  "what\\'ll happen is",
#  "what\\'s ((gonna)|(going to)) happen is",
#  'what is ((gonna)|(going to)) happen is',
#  'i want to (highlight|emphasize|underscore)',
#  '']

# %%
# Out:
# all (we\'re|I\'m) saying is

# %%
count=0
outputFile=open(folder+"WordVector-Test.txt","w")
with open(folder+"Athesim-Test.csv", encoding='ISO-8859-1') as file_obj:
    reader = csv.reader(file_obj,skipinitialspace=True)
    for row in reader:
        words=preprocess(row[0])
        print (words)
        LowerWords=[x.lower() for x in words]
        #print(words)
        cols=[]
        wordList=open(folder+"FinalWords.txt")
        with open(folder+"FinalWords.txt", encoding='ISO-8859-1') as wordFile_obj:
            for col in wordFile_obj:
                if col.replace("\n","").lower() in LowerWords:
                    cols.append(1)
                    #print ("hi")
                else:
                    cols.append(0)
            outputFile.write("|".join([str(x) for x in cols])+"\n")
        count+=1
        if count%50==0:
            print (count)

outputFile.close()

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search

# %%
folder="C:\\Users\\sriram\\OneDrive\\Computational Linguistics\\Assignments\\Assignment 4\\"
train = pd.read_csv(folder+'AtheismWords-Train.csv')

# %%
target = 'Stance'

# %%
import nltk
nltk.download()

# %%
from nltk.parse import stanford

# %%
# Out:
# Error: Could not find or load main class edu.stanford.nlp.parser.lexparser.LexicalizedParser
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-8623726c2e8a> in <module>()
# ----> 1 list(parser.raw_parse("Hello, My name is Melroy."))
#
# C:\Users\sriram\Anaconda3\lib\site-packages\nltk\parse\stanford.py in raw_parse(self, sentence, verbose)
#     130         :rtype: iter(Tree)
#     131         """
# --> 132         return next(self.raw_parse_sents([sentence], verbose))
#     133
#     134     def raw_parse_sents(self, sentences, verbose=False):
#
# C:\Users\sriram\Anaconda3\lib\site-packages\nltk\parse\stanford.py in raw_parse_sents(self, sentences, verbose)
#     148             '-outputFormat', self._OUTPUT_FORMAT,
#     149         ]
# --> 150         return self._parse_trees_output(self._execute(cmd, '\n'.join(sentences), verbose))
#     151
#     152     def tagged_parse(self, sentence, verbose=False):
#
# C:\Users\sriram\Anaconda3\lib\site-packages\nltk\parse\stanford.py in _execute(self, cmd, input_, verbose)
#     214                 cmd.append(input_file.name)
#     215                 stdout, stderr = java(cmd, classpath=self._classpath,
# --> 216                                       stdout=PIPE, stderr=PIPE)
#     217
#     218             stdout = stdout.replace(b'\xc2\xa0',b' ')
#
# C:\Users\sriram\Anaconda3\lib\site-packages\nltk\__init__.py in java(cmd, classpath, stdin, stdout, stderr, blocking)
#     132     if p.returncode != 0:
#     133         print(_decode_stdoutdata(stderr))
# --> 134         raise OSError('Java command failed : ' + str(cmd))
#     135
#     136     return (stdout, stderr)
#
# OSError: Java command failed : ['C:\\Program Files (x86)\\Java\\jre1.8.0_111\\bin\\java.exe', '-mx1000m', '-cp', 'C:\\Users\\sriram\\Desktop\\Jars\\stanford-english-corenlp-2016-01-10-models\\edu\\stanford\\nlp\\models\\lexparser\\englishPCFG.ser.gz', 'edu.stanford.nlp.parser.lexparser.LexicalizedParser', '-model', 'edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz', '-sentences', 'newline', '-outputFormat', 'penn', '-encoding', 'utf8', 'C:\\Users\\sriram\\AppData\\Local\\Temp\\tmpj7virntj']
